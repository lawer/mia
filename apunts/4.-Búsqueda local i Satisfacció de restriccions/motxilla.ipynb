# %% [markdown]
# # La motxilla
#
# El problema de la motxilla és un dels problemes més coneguts en l'àmbit de la computació. El problema consisteix en omplir una motxilla amb objectes de diferent pes i valor, de manera que es maximitzi el valor de la motxilla sense excedir el pes màxim que pot suportar.
#
# Per exemple, suposem que tenim una motxilla amb una capacitat de 100 kg i els següents objectes:
#
# | Objecte   | Pes (kg) | Valor (€) |
# |-----------|----------|-----------|
# | Coca-Cola | 1        | 1.5       |
# | Cervesa   | 2        | 2.5       |
# | Aigua     | 1        | 0.5       |
# | Cacauets  | 1        | 1.0       |
# | Patates   | 2        | 1.5       |
# | Galetes   | 1        | 1.0       |
# | Pomes     | 1        | 1.0       |
# | Taronges  | 1        | 1.0       |
# | Platans   | 1        | 1.0       |
# | Peres     | 1        | 1.0       |
# | Maduixes  | 1        | 1.0       |
# | Pinya     | 1        | 1.0       |
# | Pomes     | 1        | 1.0       |
#
# Quina combinació d'objectes podem posar a la motxilla per maximitzar el valor sense excedir el pes màxim?

# %% [markdown]
# En primer lloc necessitem definir les classes que ens permetran representar el problema, `Individu`, i `Genetic`. Una vegada definides les utilitzarem per resoldre el problema.

# %%
import random
from dataclasses import dataclass


@dataclass
class Individu:
    gens: list
    fitness: float = 0.0


class Genetic:
    def __init__(self, mida_poblacio, num_gens, valor_minim, valor_maxim, valors_discrets, funcio_fitness, prob_creuament, prob_mutacio, num_mutacions=1):

        self.mida_poblacio = mida_poblacio  # La mida de la població.
        self.num_gens = num_gens  # Número de gens per individu.
        self.valor_minim = valor_minim  # El valor mínim que pot tenir un gen.
        self.valor_maxim = valor_maxim  # El valor màxim que pot tenir un gen.
        self.valors_discrets = valors_discrets  # Booleà per determinar si els valors són discrets o no.
        self.funcio_fitness = funcio_fitness  # Funció per calcular el nivell d'adaptació d'un individu.
        self.prob_creuament = prob_creuament  # Probabilitat que es produeixi un creuament.
        self.prob_mutacio = prob_mutacio  # Probabilitat que es produeixi una mutació.
        self.num_mutacions = num_mutacions  # Número de mutacions a realitzar en cada generació.
        self.poblacio = list()  # Llista per emmagatzemar la població.
        self.generar_poblacio()  # Mètode per generar la població inicial.

    def generar_poblacio(self):
        """Genera la població inicial."""
        for _ in range(self.mida_poblacio):
            gens = self.generar_individu()
            fitness = self.funcio_fitness(gens)
            individu = Individu(gens=gens, fitness=fitness)
            self.poblacio.append(individu)

    def generar_individu(self):
        """Genera un individu aleatori."""
        individu = list()
        for _ in range(self.num_gens):
            individu.append(self.generar_gen())
        return individu

    def generar_gen(self):
        """Genera un gen aleatori."""
        if self.valors_discrets:
            return random.randint(self.valor_minim, self.valor_maxim)
        else:
            return random.uniform(self.valor_minim, self.valor_maxim)

    def ordenar_poblacio(self):
        """Ordena la població segons el seu nivell d'adaptació."""
        self.poblacio.sort(key=lambda x: x.fitness, reverse=True)

    def seleccionar_parella(self):
        """Selecciona una parella d'individus de la població. Utilitzarem el mètode del torneig."""
        parella = list()
        for _ in range(2):
            individus = random.sample(self.poblacio, 2)
            if individus[0].fitness > individus[1].fitness:
                parella.append(individus[0])
            else:
                parella.append(individus[1])
        return parella

    def creuar(self, parella):
        """Creua dos individus. Utilitzarem el mètode de creuament de 1 punt."""
        punt = random.randint(1, self.num_gens - 1)
        fill1 = parella[0].gens[:punt] + parella[1].gens[punt:]
        fill2 = parella[1].gens[:punt] + parella[0].gens[punt:]
        fitness_fill1 = self.funcio_fitness(fill1)
        fitness_fill2 = self.funcio_fitness(fill2)
        return (Individu(gens=fill1, fitness=fitness_fill1),
                Individu(gens=fill2, fitness=fitness_fill2))

    def mutar(self, fill):
        """Muta un individu. Utilitzarem el mètode de mutació uniforme."""
        for _ in range(self.num_mutacions):
            gen = random.randint(0, self.num_gens - 1)
            fill.gens[gen] = self.generar_gen()
        return fill

    def executar(self, num_generacions):
        """Executa l'algorisme genètic."""
        for i in range(num_generacions):
            self.ordenar_poblacio()

            print(f'Generació: {i}: {self.poblacio[0].fitness}')
            print(f'Individu: {self.poblacio[0].gens}')

            nova_poblacio = []

            while len(nova_poblacio) < self.mida_poblacio:
                parella = self.seleccionar_parella()
                if random.random() < self.prob_creuament:
                    fill1, fill2 = self.creuar(parella)
                    if random.random() < self.prob_mutacio:
                        fill1 = self.mutar(fill1)
                    if random.random() < self.prob_mutacio:
                        fill2 = self.mutar(fill2)
                else:
                    fill1, fill2 = parella

                nova_poblacio.append(fill1)
                nova_poblacio.append(fill2)

            self.poblacio = nova_poblacio

# %% [markdown]
# Ara que ja tenim les classes definides, podem començar a resoldre el problema. En primer lloc definirem les variables que necessitem per resoldre el problema.

# %%
PES_MAXIM = 100
PRODUCTES = [
    ('Coca-Cola', 1, 1.5),
    ('Cervesa', 2, 2.5),
    ('Aigua', 1, 0.5),
    ('Cacauets', 1, 1.0),
    ('Patates', 2, 1.5),
    ('Galetes', 1, 1.0),
    ('Pomes', 1, 1.0),
    ('Taronges', 1, 1.0),
    ('Platans', 1, 1.0),
    ('Peres', 1, 1.0),
    ('Maduixes', 1, 1.0),
    ('Pinya', 1, 1.0),
    ('Pomes', 1, 1.0)
]

# %% [markdown]
# Per fer-ho, primer necessitem definir la funció de fitness. En aquest cas, la funció de fitness serà la suma dels valors dels objectes que hi ha a la motxilla. A més, necessitem definir els gens que utilitzarem per representar cada objecte. En aquest cas, utilitzarem un gen per cada objecte, i el valor del gen serà el nombre d'objectes d'aquell tipus que hi ha a la motxilla. Per exemple, si el gen 0 té el valor 2, això vol dir que hi ha 2 cerveses a la motxilla. Així doncs, la funció de fitness serà:

# %%
def funcio_fitness(gens):
    """Funció de fitness."""
    valor = sum(gens[i] * PRODUCTES[i][2] for i in range(len(gens)))
    pes = sum(gens[i] * PRODUCTES[i][1] for i in range(len(gens)))
    
    exces = PES_MAXIM - pes
    if exces < 0:
        valor = valor + exces * 1000
    
    print(f'Valor: {valor}, Pes: {pes}')
    return valor

# %% [markdown]
# Ara que ja tenim la funció de fitness definida, podem crear l'algorisme genètic. En aquest cas, utilitzarem els següents paràmetres:

# %%
mida_poblacio = 100
num_gens = len(PRODUCTES)
valor_minim = 0
valor_maxim = 10
valors_discrets = True
prob_creuament = 0.8
prob_mutacio = 0.1
num_mutacions = 1

# %% [markdown]
# Ara ja podem crear l'algorisme genètic i executar-lo.

# %%
genetic = Genetic(mida_poblacio=mida_poblacio,
                  num_gens=num_gens,
                  valor_minim=valor_minim,
                  valor_maxim=valor_maxim,
                  valors_discrets=valors_discrets,
                  funcio_fitness=funcio_fitness,
                  prob_creuament=prob_creuament,
                  prob_mutacio=prob_mutacio,
                  num_mutacions=num_mutacions)
genetic.executar(num_generacions=100)
# Out:
# Valor: 82.5, Pes: 80
# Valor: 85.5, Pes: 83
# Valor: 40.5, Pes: 42
# Valor: 78.0, Pes: 80
# Valor: 82.0, Pes: 82
# Valor: 87.5, Pes: 91
# Valor: 83.0, Pes: 82
# Valor: 80.0, Pes: 75
# Valor: 85.0, Pes: 79
# Valor: 65.0, Pes: 66
# Valor: 77.0, Pes: 79
# Valor: 68.5, Pes: 70
# Valor: 83.5, Pes: 84
# Valor: 69.5, Pes: 68
# Valor: 77.0, Pes: 75
# Valor: 51.0, Pes: 54
# Valor: 48.0, Pes: 50
# Valor: 90.0, Pes: 92
# Valor: 56.0, Pes: 63
# Valor: 78.5, Pes: 75
# Valor: 85.5, Pes: 85
# Valor: 90.5, Pes: 89
# Valor: 80.5, Pes: 83
# Valor: 105.5, Pes: 99
# Valor: 77.0, Pes: 81
# Valor: 81.0, Pes: 78
# Valor: 64.0, Pes: 61
# Valor: 57.5, Pes: 57
# Valor: 69.5, Pes: 70
# Valor: 67.0, Pes: 65
# Valor: 86.5, Pes: 85
# Valor: 52.5, Pes: 50
# Valor: 89.5, Pes: 87
# Valor: 61.0, Pes: 58
# Valor: 56.0, Pes: 58
# Valor: 66.0, Pes: 73
# Valor: 78.0, Pes: 80
# Valor: 86.0, Pes: 89
# Valor: 80.0, Pes: 77
# Valor: 62.5, Pes: 66
# Valor: 52.5, Pes: 53
# Valor: 76.0, Pes: 74
# Valor: 57.0, Pes: 61
# Valor: 74.0, Pes: 70
# Valor: 79.0, Pes: 73
# Valor: 93.0, Pes: 93
# Valor: 54.0, Pes: 56
# Valor: 79.0, Pes: 76
# Valor: 70.5, Pes: 68
# Valor: 73.5, Pes: 70
# Valor: 82.0, Pes: 82
# Valor: 81.5, Pes: 76
# Valor: 66.5, Pes: 76
# Valor: 60.5, Pes: 66
# Valor: 87.5, Pes: 84
# Valor: 94.5, Pes: 95
# Valor: 65.5, Pes: 67
# Valor: 78.0, Pes: 81
# Valor: 71.5, Pes: 67
# Valor: 55.5, Pes: 56
# Valor: 76.5, Pes: 77
# Valor: 63.5, Pes: 61
# Valor: 78.0, Pes: 85
# Valor: 64.0, Pes: 66
# Valor: 74.0, Pes: 74
# Valor: 75.0, Pes: 77
# Valor: 66.0, Pes: 62
# Valor: 91.5, Pes: 95
# Valor: 66.5, Pes: 68
# Valor: 86.0, Pes: 88
# Valor: 69.5, Pes: 69
# Valor: 47.0, Pes: 49
# Valor: 84.0, Pes: 81
# Valor: 73.5, Pes: 78
# Valor: 56.0, Pes: 60
# Valor: 67.0, Pes: 65
# Valor: 72.5, Pes: 73
# Valor: 71.0, Pes: 72
# Valor: 61.0, Pes: 59
# Valor: 100.5, Pes: 100
# Valor: 75.5, Pes: 72
# Valor: 54.5, Pes: 54
# Valor: 75.5, Pes: 78
# Valor: 61.5, Pes: 67
# Valor: 100.5, Pes: 100
# Valor: 90.0, Pes: 88
# Valor: 72.0, Pes: 65
# Valor: 95.5, Pes: 92
# Valor: 67.5, Pes: 70
# Valor: 77.5, Pes: 82
# Valor: 86.5, Pes: 89
# Valor: 72.0, Pes: 75
# Valor: 79.5, Pes: 78
# Valor: 76.0, Pes: 79
# Valor: 98.0, Pes: 97
# Valor: 86.0, Pes: 84
# Valor: 96.5, Pes: 94
# Valor: 77.5, Pes: 73
# Valor: 58.5, Pes: 62
# Valor: 82.5, Pes: 81
# Generació: 0: 105.5
# Individu: [10, 10, 0, 2, 7, 9, 6, 4, 8, 10, 10, 5, 1]
# Valor: 90.0, Pes: 87
# Valor: 51.5, Pes: 51
# Valor: 95.5, Pes: 98
# Valor: 72.5, Pes: 76
# Valor: 74.0, Pes: 76
# Valor: 94.5, Pes: 93
# Valor: 75.5, Pes: 73
# Valor: 90.0, Pes: 85
# Valor: 71.5, Pes: 74
# Valor: 88.0, Pes: 85
# Valor: 59.0, Pes: 68
# Valor: 85.5, Pes: 89
# Valor: 74.5, Pes: 79
# Valor: -2896.5, Pes: 103
# Valor: 80.0, Pes: 80
# Valor: 69.5, Pes: 68
# Valor: 66.0, Pes: 62
# Valor: 67.5, Pes: 69
# Valor: 70.5, Pes: 72
# Valor: 73.5, Pes: 70
# Valor: 87.0, Pes: 84
# Valor: 82.0, Pes: 82
# Valor: 80.0, Pes: 87
# Valor: 83.0, Pes: 77
# Valor: 101.5, Pes: 95
# Valor: 91.5, Pes: 95
# Valor: 94.5, Pes: 90
# Valor: 76.0, Pes: 72
# Valor: 91.5, Pes: 95
# Valor: 91.5, Pes: 95
# Valor: 85.5, Pes: 86
# Valor: 80.5, Pes: 79
# Valor: 81.0, Pes: 80
# Valor: 76.0, Pes: 76
# Valor: 97.5, Pes: 92
# Valor: 80.5, Pes: 78
# Valor: 87.0, Pes: 91
# Valor: 63.0, Pes: 69
# Valor: 88.5, Pes: 87
# Valor: 76.0, Pes: 76
# Valor: 96.5, Pes: 99
# Valor: 64.0, Pes: 66
# Valor: 78.0, Pes: 76
# Valor: 84.0, Pes: 77
# Valor: 91.0, Pes: 88
# Valor: 91.5, Pes: 94
# Valor: 52.0, Pes: 55
# Valor: 81.5, Pes: 86
# Valor: 71.5, Pes: 69
# Valor: 82.5, Pes: 81
# Valor: 64.5, Pes: 69
# Valor: -901.0, Pes: 101
# Valor: 81.5, Pes: 84
# Valor: 82.0, Pes: 84
# Valor: 93.5, Pes: 90
# Valor: 81.0, Pes: 80
# Valor: 54.5, Pes: 56
# Valor: 95.0, Pes: 92
# Valor: 84.5, Pes: 83
# Valor: 95.0, Pes: 95
# Valor: 91.0, Pes: 93
# Valor: 91.5, Pes: 89
# Valor: 74.5, Pes: 72
# Valor: 75.0, Pes: 72
# Valor: 65.0, Pes: 69
# Valor: 84.5, Pes: 88
# Valor: 86.0, Pes: 85
# Valor: 84.0, Pes: 78
# Valor: 76.0, Pes: 81
# Valor: 93.0, Pes: 91
# Valor: 78.0, Pes: 79
# Valor: 96.5, Pes: 95
# Valor: 65.5, Pes: 68
# Valor: -6892.0, Pes: 107
# Generació: 1: 101.5
# Individu: [10, 10, 0, 2, 7, 9, 6, 4, 8, 7, 7, 4, 4]
# Valor: 75.0, Pes: 72
# Valor: 79.0, Pes: 76
# Valor: -3895.5, Pes: 104
# Valor: 76.5, Pes: 76
# Valor: -10886.5, Pes: 111
# Valor: 76.0, Pes: 81
# Valor: 74.5, Pes: 72
# Valor: 82.5, Pes: 82
# Valor: 85.5, Pes: 83
# Valor: -901.0, Pes: 101
# Valor: 100.0, Pes: 95
# Valor: 86.5, Pes: 84
# Valor: 97.5, Pes: 100
# Valor: 72.5, Pes: 70
# Valor: 71.5, Pes: 79
# Valor: 94.0, Pes: 97
# Valor: 104.5, Pes: 98
# Valor: 71.5, Pes: 76
# Valor: 79.0, Pes: 76
# Valor: 90.5, Pes: 93
# Valor: 98.5, Pes: 97
# Valor: 84.0, Pes: 86
# Valor: 92.5, Pes: 90
# Valor: 97.0, Pes: 92
# Valor: 87.0, Pes: 84
# Valor: 67.0, Pes: 67
# Valor: 93.0, Pes: 90
# Valor: 95.5, Pes: 92
# Valor: 83.5, Pes: 87
# Valor: 80.5, Pes: 84
# Valor: 94.5, Pes: 92
# Valor: 79.0, Pes: 81
# Valor: -1897.0, Pes: 102
# Valor: 86.5, Pes: 90
# Valor: 76.0, Pes: 71
# Valor: 87.5, Pes: 84
# Valor: 91.5, Pes: 95
# Valor: 95.5, Pes: 98
# Valor: 91.0, Pes: 82
# Valor: 100.5, Pes: 95
# Valor: 76.5, Pes: 79
# Valor: 67.0, Pes: 68
# Valor: 76.0, Pes: 77
# Valor: 91.5, Pes: 91
# Valor: 76.0, Pes: 72
# Valor: 84.5, Pes: 83
# Valor: 85.5, Pes: 84
# Valor: 89.5, Pes: 87
# Valor: 94.5, Pes: 90
# Valor: 94.5, Pes: 90
# Valor: 69.0, Pes: 65
# Valor: -8890.0, Pes: 109
# Valor: 73.0, Pes: 75
# Valor: -5893.0, Pes: 106
# Valor: 87.0, Pes: 82
# Valor: 94.5, Pes: 98
# Valor: 86.5, Pes: 89
# Valor: 88.0, Pes: 85
# Valor: 81.5, Pes: 84
# Valor: 82.5, Pes: 80
# Valor: 79.5, Pes: 79
# Valor: 83.5, Pes: 85
# Valor: 68.5, Pes: 69
# Valor: 92.0, Pes: 92
# Valor: 98.5, Pes: 93
# Valor: 93.5, Pes: 92
# Valor: 76.5, Pes: 78
# Valor: 80.5, Pes: 78
# Valor: 87.5, Pes: 84
# Valor: 81.0, Pes: 76
# Generació: 2: 104.5
# Individu: [10, 10, 0, 2, 7, 9, 6, 4, 8, 7, 7, 4, 7]
# Valor: 70.0, Pes: 71
# Valor: 91.5, Pes: 91
# Valor: 92.0, Pes: 92
# Valor: 96.5, Pes: 95
# Valor: 70.5, Pes: 72
# Valor: 101.0, Pes: 99
# Valor: 88.5, Pes: 87
# Valor: 94.5, Pes: 98
# Valor: 103.5, Pes: 98
# Valor: 87.5, Pes: 90
# Valor: 96.0, Pes: 91
# Valor: 77.5, Pes: 80
# Valor: 89.5, Pes: 88
# Valor: 99.0, Pes: 99
# Valor: 95.5, Pes: 95
# Valor: 86.5, Pes: 84
# Valor: -1902.0, Pes: 102
# Valor: 78.5, Pes: 76
# Valor: 91.5, Pes: 88
# Valor: 96.5, Pes: 94
# Valor: 60.5, Pes: 59
# Valor: -10890.0, Pes: 111
# Valor: 83.5, Pes: 82
# Valor: 92.0, Pes: 89
# Valor: 93.0, Pes: 89
# Valor: 96.5, Pes: 96
# Valor: 91.0, Pes: 88
# Valor: 87.5, Pes: 87
# Valor: 88.0, Pes: 83
# Valor: 97.5, Pes: 96
# Valor: 100.5, Pes: 98
# Valor: 73.5, Pes: 76
# Valor: 84.0, Pes: 86
# Valor: 94.5, Pes: 93
# Valor: 81.5, Pes: 78
# Valor: 98.0, Pes: 98
# Valor: 82.5, Pes: 85
# Valor: 94.5, Pes: 97
# Valor: 68.5, Pes: 67
# Valor: 89.0, Pes: 86
# Valor: 83.5, Pes: 82
# Valor: 95.0, Pes: 98
# Valor: 72.5, Pes: 75
# Valor: 92.0, Pes: 89
# Valor: 91.5, Pes: 94
# Valor: 80.5, Pes: 79
# Valor: 89.0, Pes: 84
# Valor: -902.5, Pes: 101
# Valor: 102.0, Pes: 97
# Valor: 89.0, Pes: 91
# Valor: 81.0, Pes: 85
# Valor: 87.0, Pes: 89
# Valor: 92.5, Pes: 96
# Valor: 106.5, Pes: 100
# Valor: 97.0, Pes: 92
# Valor: 97.0, Pes: 92
# Valor: 98.5, Pes: 98
# Valor: 84.5, Pes: 82
# Valor: 89.5, Pes: 88
# Valor: 91.5, Pes: 94
# Valor: 87.5, Pes: 86
# Valor: -7894.5, Pes: 108
# Valor: 100.5, Pes: 97
# Valor: 89.5, Pes: 93
# Valor: 85.0, Pes: 87
# Valor: 96.0, Pes: 93
# Valor: 94.0, Pes: 91
# Valor: 88.0, Pes: 88
# Valor: 101.5, Pes: 95
# Valor: 94.5, Pes: 94
# Valor: 101.5, Pes: 95
# Valor: -1901.5, Pes: 102
# Valor: 76.0, Pes: 73
# Valor: 82.5, Pes: 80
# Valor: -2899.5, Pes: 103
# Valor: 92.5, Pes: 91
# Valor: 99.0, Pes: 96
# Valor: 92.5, Pes: 91
# Generació: 3: 106.5
# Individu: [10, 10, 0, 2, 7, 9, 6, 4, 8, 7, 7, 5, 8]
# Valor: 91.5, Pes: 90
# Valor: -5892.5, Pes: 106
# Valor: 95.5, Pes: 99
# Valor: 99.5, Pes: 94
# Valor: -4897.5, Pes: 105
# Valor: 85.0, Pes: 82
# Valor: 81.5, Pes: 80
# Valor: 96.5, Pes: 95
# Valor: 105.0, Pes: 100
# Valor: 92.5, Pes: 88
# Valor: 88.0, Pes: 83
# Valor: 82.0, Pes: 86
# Valor: 69.0, Pes: 69
# Valor: -4895.5, Pes: 105
# Valor: 76.0, Pes: 78
# Valor: 96.5, Pes: 99
# Valor: 98.5, Pes: 98
# Valor: 84.0, Pes: 75
# Valor: 95.5, Pes: 93
# Valor: 95.5, Pes: 92
# Valor: -3891.0, Pes: 104
# Valor: 84.0, Pes: 87
# Valor: 91.5, Pes: 90
# Valor: 87.0, Pes: 84
# Valor: 98.0, Pes: 98
# Valor: 97.5, Pes: 92
# Valor: 91.0, Pes: 89
# Valor: -901.0, Pes: 101
# Valor: 94.5, Pes: 90
# Valor: 88.0, Pes: 85
# Valor: 100.0, Pes: 100
# Valor: 80.5, Pes: 77
# Valor: 97.5, Pes: 90
# Valor: 95.0, Pes: 93
# Valor: 96.0, Pes: 91
# Valor: 102.5, Pes: 96
# Valor: 93.5, Pes: 97
# Valor: 94.0, Pes: 94
# Valor: 90.0, Pes: 87
# Valor: 101.0, Pes: 96
# Valor: 96.5, Pes: 95
# Valor: 97.5, Pes: 100
# Valor: 87.5, Pes: 86
# Valor: 93.0, Pes: 88
# Valor: 88.0, Pes: 89
# Valor: 90.0, Pes: 84
# Valor: 85.0, Pes: 82
# Valor: 94.0, Pes: 89
# Valor: 103.5, Pes: 97
# Valor: 99.0, Pes: 94
# Valor: 93.0, Pes: 93
# Valor: 102.0, Pes: 99
# Valor: 87.5, Pes: 85
# Valor: 97.0, Pes: 97
# Valor: -1896.5, Pes: 102
# Valor: 89.5, Pes: 88
# Valor: 93.0, Pes: 89
# Valor: 86.5, Pes: 84
# Valor: 92.5, Pes: 92
# Valor: 89.5, Pes: 93
# Valor: 94.5, Pes: 92
# Valor: 81.5, Pes: 79
# Valor: 100.5, Pes: 100
# Valor: 96.5, Pes: 94
# Valor: -1891.5, Pes: 102
# Valor: 92.5, Pes: 91
# Valor: 85.5, Pes: 84
# Valor: 101.0, Pes: 98
# Valor: 92.5, Pes: 91
# Valor: 89.5, Pes: 88
# Valor: 91.5, Pes: 90
# Valor: 91.5, Pes: 89
# Valor: 85.5, Pes: 82
# Valor: 92.0, Pes: 96
# Valor: -7894.5, Pes: 108
# Valor: 86.5, Pes: 83
# Valor: 100.0, Pes: 96
# Valor: 91.0, Pes: 91
# Generació: 4: 105.0
# Individu: [10, 10, 6, 6, 4, 7, 1, 8, 1, 9, 9, 7, 8]
# Valor: 96.5, Pes: 91
# Valor: 88.0, Pes: 86
# Valor: 100.0, Pes: 95
# Valor: -2897.0, Pes: 103
# Valor: 90.5, Pes: 94
# Valor: 94.5, Pes: 98
# Valor: 87.5, Pes: 85
# Valor: -3891.0, Pes: 104
# Valor: 105.5, Pes: 98
# Valor: 98.0, Pes: 94
# Valor: 78.0, Pes: 79
# Valor: 95.0, Pes: 92
# Valor: 89.0, Pes: 87
# Valor: 98.5, Pes: 96
# Valor: 92.5, Pes: 88
# Valor: 96.5, Pes: 94
# Valor: -1895.0, Pes: 102
# Valor: 93.5, Pes: 94
# Valor: -5893.5, Pes: 106
# Valor: 81.0, Pes: 82
# Valor: -2890.5, Pes: 103
# Valor: 94.5, Pes: 91
# Valor: 97.5, Pes: 95
# Valor: 94.5, Pes: 98
# Valor: 96.5, Pes: 95
# Valor: 87.0, Pes: 85
# Valor: 85.0, Pes: 82
# Valor: 98.5, Pes: 96
# Valor: 84.0, Pes: 80
# Valor: 90.5, Pes: 90
# Valor: -5891.5, Pes: 106
# Valor: 80.0, Pes: 74
# Valor: 105.5, Pes: 100
# Valor: 87.0, Pes: 84
# Valor: -12886.0, Pes: 113
# Valor: 76.0, Pes: 77
# Valor: 99.5, Pes: 98
# Valor: 95.0, Pes: 89
# Valor: 88.5, Pes: 87
# Valor: 102.5, Pes: 96
# Valor: 97.5, Pes: 96
# Valor: 96.0, Pes: 95
# Valor: 99.0, Pes: 93
# Valor: 85.5, Pes: 81
# Valor: 102.0, Pes: 97
# Valor: 96.0, Pes: 91
# Valor: 96.0, Pes: 95
# Valor: 83.5, Pes: 85
# Valor: 92.5, Pes: 93
# Valor: 100.5, Pes: 98
# Valor: 101.0, Pes: 98
# Valor: 102.5, Pes: 96
# Valor: 96.5, Pes: 92
# Valor: -1896.5, Pes: 102
# Valor: -3895.5, Pes: 104
# Valor: 90.5, Pes: 88
# Valor: 100.5, Pes: 98
# Valor: 95.0, Pes: 91
# Valor: 92.5, Pes: 91
# Valor: 82.0, Pes: 79
# Valor: 91.0, Pes: 87
# Valor: -902.5, Pes: 101
# Valor: 95.0, Pes: 93
# Valor: 91.0, Pes: 87
# Valor: -5890.0, Pes: 106
# Valor: 78.5, Pes: 75
# Valor: 104.0, Pes: 99
# Valor: 82.5, Pes: 77
# Valor: 94.0, Pes: 91
# Valor: 94.0, Pes: 91
# Valor: -12886.0, Pes: 113
# Valor: 79.5, Pes: 78
# Valor: -895.0, Pes: 101
# Valor: 85.5, Pes: 80
# Valor: 97.5, Pes: 97
# Valor: 90.5, Pes: 89
# Valor: 76.5, Pes: 76
# Valor: 88.0, Pes: 83
# Valor: 97.0, Pes: 92
# Valor: 101.5, Pes: 99
# Generació: 5: 105.5
# Individu: [10, 10, 0, 2, 5, 7, 5, 8, 5, 7, 9, 7, 8]
# Valor: 96.5, Pes: 93
# Valor: 100.0, Pes: 95
# Valor: -5893.5, Pes: 106
# Valor: 89.5, Pes: 87
# Valor: 92.0, Pes: 89
# Valor: -2891.5, Pes: 103
# Valor: 99.0, Pes: 95
# Valor: 91.0, Pes: 89
# Valor: 84.5, Pes: 83
# Valor: -892.5, Pes: 101
# Valor: 96.5, Pes: 96
# Valor: 93.5, Pes: 89
# Valor: 92.0, Pes: 89
# Valor: -901.5, Pes: 101
# Valor: 93.0, Pes: 89
# Valor: 102.0, Pes: 97
# Valor: 83.0, Pes: 79
# Valor: 94.5, Pes: 89
# Valor: 95.0, Pes: 94
# Valor: -3889.0, Pes: 104
# Valor: 94.0, Pes: 91
# Valor: 101.0, Pes: 98
# Valor: -900.5, Pes: 101
# Valor: 89.5, Pes: 86
# Valor: 100.5, Pes: 100
# Valor: 100.5, Pes: 100
# Valor: 93.0, Pes: 89
# Valor: 94.5, Pes: 92
# Valor: 92.5, Pes: 90
# Valor: 91.5, Pes: 86
# Valor: 99.5, Pes: 97
# Valor: 102.5, Pes: 95
# Valor: 97.5, Pes: 94
# Valor: 102.0, Pes: 97
# Valor: 104.0, Pes: 99
# Valor: 100.5, Pes: 97
# Valor: 90.0, Pes: 87
# Valor: 98.5, Pes: 96
# Valor: 86.0, Pes: 81
# Valor: -3893.5, Pes: 104
# Valor: -9883.5, Pes: 110
# Valor: 92.5, Pes: 92
# Valor: -1896.0, Pes: 102
# Valor: 94.5, Pes: 89
# Valor: 94.0, Pes: 89
# Valor: 84.0, Pes: 86
# Valor: 97.5, Pes: 95
# Valor: 105.5, Pes: 99
# Valor: 89.0, Pes: 85
# Valor: 99.5, Pes: 98
# Valor: 99.0, Pes: 94
# Valor: 92.0, Pes: 89
# Valor: 93.5, Pes: 92
# Valor: 95.5, Pes: 94
# Valor: 97.0, Pes: 89
# Valor: -1894.5, Pes: 102
# Valor: 94.5, Pes: 98
# Valor: -902.5, Pes: 101
# Valor: 104.0, Pes: 99
# Valor: 96.5, Pes: 92
# Valor: 100.5, Pes: 95
# Valor: 94.5, Pes: 93
# Valor: 89.0, Pes: 84
# Valor: -1897.0, Pes: 102
# Valor: 99.5, Pes: 99
# Valor: 93.0, Pes: 88
# Valor: 90.0, Pes: 86
# Valor: 88.5, Pes: 86
# Valor: -16876.5, Pes: 117
# Valor: 89.5, Pes: 88
# Valor: 97.5, Pes: 97
# Valor: -4888.5, Pes: 105
# Valor: 98.0, Pes: 93
# Valor: 95.0, Pes: 93
# Valor: -892.5, Pes: 101
# Valor: 89.0, Pes: 87
# Valor: -9883.5, Pes: 110
# Valor: 97.5, Pes: 90
# Valor: 84.5, Pes: 84
# Valor: 92.5, Pes: 93
# Generació: 6: 105.5
# Individu: [10, 10, 0, 2, 7, 10, 10, 4, 3, 4, 7, 5, 10]
# Valor: 91.5, Pes: 88
# Valor: 98.0, Pes: 94
# Valor: 93.5, Pes: 90
# Valor: 97.5, Pes: 96
# Valor: 100.0, Pes: 97
# Valor: 96.0, Pes: 90
# Valor: 98.5, Pes: 97
# Valor: 95.5, Pes: 91
# Valor: 90.5, Pes: 90
# Valor: -3891.0, Pes: 104
# Valor: 97.0, Pes: 92
# Valor: 100.5, Pes: 97
# Valor: -3893.5, Pes: 104
# Valor: 95.0, Pes: 94
# Valor: -10887.5, Pes: 111
# Valor: 88.5, Pes: 81
# Valor: 102.0, Pes: 98
# Valor: 98.0, Pes: 95
# Valor: 80.0, Pes: 74
# Valor: -7889.5, Pes: 108
# Valor: -4896.5, Pes: 105
# Valor: 95.5, Pes: 95
# Valor: -1894.5, Pes: 102
# Valor: 94.5, Pes: 94
# Valor: -3897.0, Pes: 104
# Valor: 92.5, Pes: 92
# Valor: 100.5, Pes: 98
# Valor: 90.0, Pes: 86
# Valor: 95.5, Pes: 93
# Valor: 103.0, Pes: 95
# Valor: 92.0, Pes: 88
# Valor: 80.5, Pes: 79
# Valor: 95.5, Pes: 93
# Valor: 99.0, Pes: 94
# Valor: 91.5, Pes: 91
# Valor: 100.0, Pes: 95
# Valor: 96.0, Pes: 91
# Valor: 98.0, Pes: 93
# Valor: -4894.0, Pes: 105
# Valor: 91.0, Pes: 88
# Valor: 101.0, Pes: 97
# Valor: 98.5, Pes: 95
# Valor: 86.0, Pes: 84
# Valor: 101.0, Pes: 96
# Valor: 87.0, Pes: 84
# Valor: 103.5, Pes: 98
# Valor: -891.5, Pes: 101
# Valor: 83.5, Pes: 87
# Valor: 96.5, Pes: 91
# Valor: 100.5, Pes: 93
# Valor: 90.5, Pes: 88
# Valor: -2896.5, Pes: 103
# Valor: 101.5, Pes: 99
# Valor: 100.5, Pes: 100
# Valor: 95.0, Pes: 90
# Valor: 100.0, Pes: 96
# Valor: 92.0, Pes: 87
# Valor: -2895.0, Pes: 103
# Valor: -8885.5, Pes: 109
# Valor: 85.5, Pes: 88
# Valor: -6890.5, Pes: 107
# Valor: 93.0, Pes: 85
# Valor: 83.5, Pes: 83
# Valor: 97.5, Pes: 93
# Valor: 98.5, Pes: 93
# Valor: 98.5, Pes: 91
# Valor: -3889.5, Pes: 104
# Valor: 89.5, Pes: 88
# Valor: 97.5, Pes: 95
# Valor: 102.5, Pes: 95
# Valor: 87.0, Pes: 84
# Valor: 86.0, Pes: 81
# Valor: 105.5, Pes: 100
# Valor: 96.5, Pes: 92
# Valor: 98.5, Pes: 98
# Valor: 98.5, Pes: 94
# Valor: -2895.5, Pes: 103
# Valor: 90.5, Pes: 83
# Valor: 100.5, Pes: 97
# Valor: 80.5, Pes: 79
# Valor: 88.5, Pes: 88
# Valor: 99.0, Pes: 96
# Valor: 100.0, Pes: 97
# Valor: 100.0, Pes: 97
# Valor: 92.0, Pes: 87
# Valor: 101.0, Pes: 96
# Generació: 7: 105.5
# Individu: [9, 10, 3, 9, 5, 10, 1, 6, 10, 3, 3, 8, 8]
# Valor: 96.0, Pes: 92
# Valor: 99.5, Pes: 94
# Valor: 101.0, Pes: 95
# Valor: 100.5, Pes: 96
# Valor: 80.0, Pes: 77
# Valor: -4893.5, Pes: 105
# Valor: 71.0, Pes: 69
# Valor: -1898.0, Pes: 102
# Valor: 94.5, Pes: 91
# Valor: -893.5, Pes: 101
# Valor: 97.0, Pes: 92
# Valor: 91.5, Pes: 84
# Valor: 88.5, Pes: 88
# Valor: -8888.0, Pes: 109
# Valor: 96.5, Pes: 94
# Valor: 96.5, Pes: 93
# Valor: 78.5, Pes: 73
# Valor: -19877.5, Pes: 120
# Valor: 103.0, Pes: 100
# Valor: 96.5, Pes: 94
# Valor: 95.5, Pes: 93
# Valor: 91.0, Pes: 89
# Valor: 95.0, Pes: 95
# Valor: 100.5, Pes: 96
# Valor: 90.5, Pes: 90
# Valor: 92.5, Pes: 85
# Valor: 101.0, Pes: 95
# Valor: 94.0, Pes: 90
# Valor: 99.5, Pes: 91
# Valor: 96.5, Pes: 94
# Valor: 85.5, Pes: 80
# Valor: -16881.5, Pes: 117
# Valor: 98.5, Pes: 94
# Valor: 92.0, Pes: 88
# Valor: 102.5, Pes: 95
# Valor: 92.0, Pes: 89
# Valor: 101.5, Pes: 94
# Valor: 92.0, Pes: 91
# Valor: -6890.5, Pes: 107
# Valor: 91.5, Pes: 91
# Valor: -3893.0, Pes: 104
# Valor: 94.5, Pes: 92
# Valor: 90.0, Pes: 85
# Valor: 100.0, Pes: 97
# Valor: 96.0, Pes: 92
# Valor: -1896.5, Pes: 102
# Valor: 80.0, Pes: 75
# Valor: 95.5, Pes: 91
# Valor: 84.0, Pes: 81
# Valor: 104.0, Pes: 99
# Valor: 95.5, Pes: 94
# Valor: 99.0, Pes: 94
# Valor: 90.5, Pes: 90
# Valor: 97.5, Pes: 97
# Valor: 95.0, Pes: 94
# Valor: 100.5, Pes: 100
# Valor: 92.5, Pes: 91
# Valor: 101.0, Pes: 95
# Valor: 89.5, Pes: 84
# Valor: -11885.5, Pes: 112
# Valor: 96.5, Pes: 93
# Valor: 97.0, Pes: 93
# Valor: 107.0, Pes: 100
# Valor: 103.0, Pes: 100
# Valor: 88.0, Pes: 86
# Valor: 94.5, Pes: 94
# Valor: 95.0, Pes: 91
# Valor: -5889.0, Pes: 106
# Valor: 93.5, Pes: 92
# Valor: -7890.5, Pes: 108
# Valor: 96.5, Pes: 94
# Valor: 96.5, Pes: 93
# Valor: -8889.0, Pes: 109
# Valor: 85.5, Pes: 82
# Valor: 98.0, Pes: 94
# Valor: 98.0, Pes: 94
# Valor: 102.5, Pes: 100
# Valor: 97.5, Pes: 94
# Generació: 8: 107.0
# Individu: [9, 10, 0, 2, 5, 7, 6, 10, 8, 9, 9, 0, 10]
# Valor: 104.0, Pes: 98
# Valor: 93.5, Pes: 88
# Valor: -4890.0, Pes: 105
# Valor: 103.0, Pes: 99
# Valor: 94.5, Pes: 91
# Valor: 94.0, Pes: 90
# Valor: 93.0, Pes: 89
# Valor: -3896.0, Pes: 104
# Valor: 102.5, Pes: 98
# Valor: 99.0, Pes: 93
# Valor: 79.5, Pes: 73
# Valor: -4890.5, Pes: 105
# Valor: 106.0, Pes: 100
# Valor: 98.0, Pes: 95
# Valor: -8888.5, Pes: 109
# Valor: 104.0, Pes: 98
# Valor: 89.5, Pes: 88
# Valor: -2894.0, Pes: 103
# Valor: 88.0, Pes: 87
# Valor: 101.5, Pes: 99
# Valor: 96.0, Pes: 92
# Valor: 97.0, Pes: 93
# Valor: 84.5, Pes: 84
# Valor: -8886.0, Pes: 109
# Valor: 103.0, Pes: 100
# Valor: 96.5, Pes: 93
# Valor: 101.0, Pes: 98
# Valor: -1897.5, Pes: 102
# Valor: 99.5, Pes: 99
# Valor: 96.0, Pes: 92
# Valor: 100.5, Pes: 93
# Valor: 103.5, Pes: 95
# Valor: -8889.0, Pes: 109
# Valor: 89.0, Pes: 88
# Valor: 94.5, Pes: 93
# Valor: 90.5, Pes: 83
# Valor: 86.0, Pes: 81
# Valor: -3892.5, Pes: 104
# Valor: 89.5, Pes: 86
# Valor: -1896.5, Pes: 102
# Valor: 99.5, Pes: 96
# Valor: -896.5, Pes: 101
# Valor: 95.5, Pes: 90
# Valor: 96.0, Pes: 92
# Valor: 102.5, Pes: 95
# Valor: 102.5, Pes: 95
# Valor: 100.0, Pes: 96
# Valor: 97.0, Pes: 93
# Valor: 82.5, Pes: 79
# Valor: -5890.0, Pes: 106
# Valor: 101.0, Pes: 93
# Valor: -3893.5, Pes: 104
# Valor: 92.0, Pes: 88
# Valor: -6890.0, Pes: 107
# Valor: 99.5, Pes: 94
# Valor: 101.5, Pes: 94
# Valor: 99.0, Pes: 94
# Valor: 98.0, Pes: 93
# Valor: 101.5, Pes: 99
# Valor: 91.5, Pes: 88
# Valor: 103.0, Pes: 96
# Valor: 102.0, Pes: 98
# Valor: -5891.5, Pes: 106
# Valor: 101.0, Pes: 95
# Valor: 99.0, Pes: 94
# Valor: 80.0, Pes: 77
# Valor: 94.0, Pes: 88
# Valor: 105.5, Pes: 98
# Valor: -3893.0, Pes: 104
# Valor: 94.5, Pes: 92
# Valor: 103.5, Pes: 98
# Valor: 99.0, Pes: 94
# Valor: 98.5, Pes: 98
# Valor: 92.0, Pes: 88
# Valor: 92.5, Pes: 90
# Valor: -5891.0, Pes: 106
# Valor: 99.5, Pes: 90
# Valor: 102.0, Pes: 100
# Valor: 96.0, Pes: 95
# Valor: 100.5, Pes: 100
# Valor: 80.5, Pes: 75
# Valor: -12884.0, Pes: 113
# Valor: -1895.5, Pes: 102
# Valor: 97.5, Pes: 89
# Generació: 9: 106.0
# Individu: [9, 10, 2, 2, 5, 7, 5, 8, 9, 4, 9, 7, 8]
# Valor: 103.5, Pes: 95
# Valor: 95.0, Pes: 90
# Valor: 99.0, Pes: 92
# Valor: 103.0, Pes: 98
# Valor: 101.0, Pes: 96
# Valor: 102.0, Pes: 96
# Valor: 93.5, Pes: 90
# Valor: -4892.0, Pes: 105
# Valor: 97.5, Pes: 91
# Valor: 103.0, Pes: 98
# Valor: -9885.5, Pes: 110
# Valor: 89.0, Pes: 81
# Valor: 98.0, Pes: 97
# Valor: 100.5, Pes: 96
# Valor: 103.0, Pes: 97
# Valor: 102.5, Pes: 93
# Valor: -2895.0, Pes: 103
# Valor: 86.0, Pes: 82
# Valor: 91.0, Pes: 85
# Valor: 89.5, Pes: 88
# Valor: 90.5, Pes: 90
# Valor: 96.0, Pes: 92
# Valor: 104.5, Pes: 99
# Valor: 90.0, Pes: 85
# Valor: 83.5, Pes: 78
# Valor: -9888.5, Pes: 110
# Valor: -5890.0, Pes: 106
# Valor: 87.5, Pes: 84
# Valor: 106.0, Pes: 100
# Valor: 104.0, Pes: 98
# Valor: 82.5, Pes: 80
# Valor: -7887.5, Pes: 108
# Valor: 93.0, Pes: 87
# Valor: -2893.5, Pes: 103
# Valor: 101.5, Pes: 99
# Valor: -8886.0, Pes: 109
# Valor: -1895.5, Pes: 102
# Valor: 97.5, Pes: 95
# Valor: 94.5, Pes: 93
# Valor: 96.5, Pes: 92
# Valor: 99.5, Pes: 94
# Valor: 100.5, Pes: 92
# Valor: 100.0, Pes: 96
# Valor: 103.5, Pes: 95
# Valor: 94.0, Pes: 89
# Valor: 104.0, Pes: 99
# Valor: 85.0, Pes: 81
# Valor: -7886.5, Pes: 108
# Valor: 99.5, Pes: 91
# Valor: 96.0, Pes: 92
# Valor: 94.0, Pes: 93
# Valor: 101.0, Pes: 96
# Valor: 96.0, Pes: 95
# Valor: -6889.5, Pes: 107
# Valor: 88.0, Pes: 82
# Valor: -1894.0, Pes: 102
# Valor: 93.0, Pes: 87
# Valor: -896.0, Pes: 101
# Valor: -1895.0, Pes: 102
# Valor: 97.5, Pes: 90
# Valor: 95.0, Pes: 91
# Valor: 99.0, Pes: 95
# Valor: 94.0, Pes: 88
# Valor: -6886.0, Pes: 107
# Valor: 102.5, Pes: 100
# Valor: -893.0, Pes: 101
# Valor: 102.0, Pes: 96
# Valor: 101.0, Pes: 96
# Valor: 99.0, Pes: 92
# Valor: 94.0, Pes: 90
# Valor: 91.5, Pes: 90
# Valor: 97.0, Pes: 91
# Valor: 93.5, Pes: 91
# Valor: -7887.5, Pes: 108
# Valor: 104.0, Pes: 98
# Valor: 99.0, Pes: 93
# Valor: 97.0, Pes: 93
# Valor: 97.0, Pes: 91
# Valor: 97.5, Pes: 94
# Valor: 93.5, Pes: 90
# Valor: -1897.5, Pes: 102
# Valor: 91.0, Pes: 86
# Valor: 102.0, Pes: 96
# Valor: 96.5, Pes: 92
# Generació: 10: 106.0
# Individu: [9, 10, 2, 2, 5, 7, 5, 8, 9, 4, 9, 7, 8]
# Valor: 100.0, Pes: 94
# Valor: 98.0, Pes: 97
# Valor: -2891.0, Pes: 103
# Valor: 88.5, Pes: 84
# Valor: 101.0, Pes: 97
# Valor: 101.0, Pes: 96
# Valor: 104.0, Pes: 100
# Valor: 100.0, Pes: 94
# Valor: 91.5, Pes: 88
# Valor: 104.0, Pes: 100
# Valor: 106.5, Pes: 98
# Valor: 95.0, Pes: 89
# Valor: 93.5, Pes: 90
# Valor: 103.5, Pes: 95
# Valor: 104.0, Pes: 100
# Valor: 95.5, Pes: 93
# Valor: -2895.5, Pes: 103
# Valor: 91.5, Pes: 87
# Valor: 103.0, Pes: 97
# Valor: 97.5, Pes: 95
# Valor: 98.5, Pes: 95
# Valor: 103.0, Pes: 97
# Valor: 93.0, Pes: 87
# Valor: 93.5, Pes: 90
# Valor: -3892.0, Pes: 104
# Valor: 94.0, Pes: 87
# Valor: 93.5, Pes: 86
# Valor: 96.0, Pes: 88
# Valor: 104.0, Pes: 99
# Valor: 100.5, Pes: 96
# Valor: 101.0, Pes: 96
# Valor: 105.0, Pes: 100
# Valor: 105.0, Pes: 98
# Valor: 96.5, Pes: 92
# Valor: 92.5, Pes: 85
# Valor: 107.5, Pes: 99
# Valor: 103.5, Pes: 98
# Valor: 101.0, Pes: 96
# Valor: -2892.0, Pes: 103
# Valor: 90.0, Pes: 84
# Valor: 95.5, Pes: 93
# Valor: -3892.0, Pes: 104
# Valor: 101.5, Pes: 92
# Valor: 103.0, Pes: 99
# Valor: 103.0, Pes: 97
# Valor: 104.0, Pes: 97
# Valor: 98.0, Pes: 97
# Valor: 103.5, Pes: 95
# Valor: 106.0, Pes: 100
# Valor: 103.5, Pes: 100
# Valor: 90.5, Pes: 87
# Valor: 97.5, Pes: 96
# Valor: 96.0, Pes: 95
# Valor: 103.0, Pes: 100
# Valor: 93.5, Pes: 91
# Valor: 103.5, Pes: 95
# Valor: 104.0, Pes: 98
# Valor: -1892.0, Pes: 102
# Valor: 100.0, Pes: 94
# Valor: 104.0, Pes: 100
# Valor: 99.0, Pes: 95
# Valor: 99.0, Pes: 94
# Valor: 94.0, Pes: 89
# Valor: -5890.0, Pes: 106
# Valor: 92.0, Pes: 86
# Valor: 100.0, Pes: 96
# Valor: 103.5, Pes: 95
# Valor: 89.5, Pes: 88
# Valor: 108.5, Pes: 99
# Valor: 97.5, Pes: 89
# Valor: 99.5, Pes: 96
# Valor: 100.5, Pes: 93
# Valor: 100.0, Pes: 94
# Valor: 94.5, Pes: 86
# Valor: -893.0, Pes: 101
# Valor: 92.5, Pes: 85
# Valor: 98.0, Pes: 92
# Valor: -1895.5, Pes: 102
# Valor: 98.0, Pes: 95
# Valor: -2891.0, Pes: 103
# Generació: 11: 108.5
# Individu: [9, 10, 0, 10, 0, 7, 5, 7, 8, 7, 10, 8, 8]
# Valor: 86.0, Pes: 81
# Valor: 103.5, Pes: 98
# Valor: 97.0, Pes: 91
# Valor: -1894.0, Pes: 102
# Valor: 103.0, Pes: 97
# Valor: 95.0, Pes: 89
# Valor: 107.5, Pes: 99
# Valor: 98.0, Pes: 92
# Valor: 98.5, Pes: 95
# Valor: 95.5, Pes: 90
# Valor: 105.5, Pes: 97
# Valor: 102.0, Pes: 98
# Valor: 99.0, Pes: 98
# Valor: 93.5, Pes: 87
# Valor: 99.0, Pes: 95
# Valor: -4891.0, Pes: 105
# Valor: 107.0, Pes: 98
# Valor: -894.5, Pes: 101
# Valor: 102.5, Pes: 95
# Valor: 94.5, Pes: 86
# Valor: 104.0, Pes: 99
# Valor: 92.5, Pes: 83
# Valor: 104.0, Pes: 100
# Valor: 102.5, Pes: 94
# Valor: 95.5, Pes: 87
# Valor: -899.0, Pes: 101
# Valor: 101.0, Pes: 97
# Valor: -2893.5, Pes: 103
# Valor: 97.0, Pes: 90
# Valor: 102.0, Pes: 95
# Valor: 101.0, Pes: 96
# Valor: 100.0, Pes: 94
# Valor: 99.0, Pes: 95
# Valor: -2892.0, Pes: 103
# Valor: 104.0, Pes: 98
# Valor: 98.0, Pes: 94
# Valor: -3891.0, Pes: 104
# Valor: 95.0, Pes: 89
# Valor: 96.5, Pes: 94
# Valor: 106.5, Pes: 99
# Valor: 101.5, Pes: 97
# Valor: 93.0, Pes: 88
# Valor: 94.0, Pes: 92
# Valor: 98.5, Pes: 94
# Valor: 99.0, Pes: 92
# Valor: -1897.0, Pes: 102
# Valor: 104.0, Pes: 94
# Valor: 107.0, Pes: 100
# Valor: 100.0, Pes: 93
# Valor: 103.0, Pes: 97
# Valor: 96.0, Pes: 93
# Valor: 101.0, Pes: 97
# Valor: 105.0, Pes: 99
# Valor: 97.0, Pes: 94
# Valor: 102.0, Pes: 98
# Valor: 105.0, Pes: 100
# Valor: 89.5, Pes: 89
# Valor: 96.5, Pes: 91
# Valor: 104.0, Pes: 98
# Valor: 97.0, Pes: 92
# Valor: 94.5, Pes: 92
# Valor: 101.0, Pes: 95
# Valor: 103.5, Pes: 100
# Valor: 89.5, Pes: 88
# Valor: 106.0, Pes: 100
# Valor: 102.0, Pes: 97
# Valor: -1894.0, Pes: 102
# Valor: 95.0, Pes: 91
# Valor: 103.5, Pes: 98
# Valor: 101.5, Pes: 98
# Valor: 104.0, Pes: 99
# Valor: 84.0, Pes: 77
# Valor: 99.5, Pes: 90
# Valor: 105.5, Pes: 97
# Valor: 98.0, Pes: 93
# Valor: 101.0, Pes: 98
# Valor: 104.0, Pes: 97
# Valor: 106.0, Pes: 100
# Valor: -5888.5, Pes: 106
# Valor: 85.0, Pes: 80
# Generació: 12: 107.5
# Individu: [10, 10, 0, 6, 3, 5, 7, 8, 9, 3, 10, 7, 8]
# Valor: 100.5, Pes: 95
# Valor: 99.0, Pes: 93
# Valor: -1893.0, Pes: 102
# Valor: 102.0, Pes: 92
# Valor: 103.0, Pes: 99
# Valor: 102.0, Pes: 96
# Valor: 95.5, Pes: 87
# Valor: -5892.5, Pes: 106
# Valor: 103.0, Pes: 98
# Valor: 101.0, Pes: 95
# Valor: 100.0, Pes: 94
# Valor: 98.0, Pes: 93
# Valor: -2893.5, Pes: 103
# Valor: 102.0, Pes: 96
# Valor: -892.0, Pes: 101
# Valor: 102.0, Pes: 96
# Valor: 105.0, Pes: 99
# Valor: 103.0, Pes: 97
# Valor: 108.5, Pes: 100
# Valor: 92.5, Pes: 84
# Valor: 96.5, Pes: 92
# Valor: 101.5, Pes: 92
# Valor: 98.0, Pes: 95
# Valor: 101.0, Pes: 94
# Valor: 104.0, Pes: 99
# Valor: 100.0, Pes: 94
# Valor: 103.0, Pes: 98
# Valor: 95.5, Pes: 91
# Valor: 96.0, Pes: 91
# Valor: 94.0, Pes: 89
# Valor: 102.0, Pes: 95
# Valor: 104.5, Pes: 96
# Valor: 99.0, Pes: 95
# Valor: 100.0, Pes: 96
# Valor: 104.5, Pes: 99
# Valor: 101.0, Pes: 95
# Valor: 100.0, Pes: 96
# Valor: 105.0, Pes: 100
# Valor: 98.0, Pes: 95
# Valor: 103.0, Pes: 96
# Valor: 106.0, Pes: 97
# Valor: 98.5, Pes: 97
# Valor: 99.5, Pes: 90
# Valor: -5891.5, Pes: 106
# Valor: 104.0, Pes: 99
# Valor: 100.5, Pes: 95
# Valor: 93.0, Pes: 91
# Valor: 101.5, Pes: 96
# Valor: 104.0, Pes: 98
# Valor: 96.5, Pes: 91
# Valor: 97.5, Pes: 96
# Valor: 104.0, Pes: 97
# Valor: 100.0, Pes: 94
# Valor: 104.0, Pes: 100
# Valor: -8888.5, Pes: 109
# Valor: 94.0, Pes: 88
# Valor: 105.0, Pes: 99
# Valor: 104.0, Pes: 98
# Valor: 104.5, Pes: 96
# Valor: 105.0, Pes: 99
# Valor: -3889.0, Pes: 104
# Valor: 101.5, Pes: 93
# Valor: 101.0, Pes: 95
# Valor: 105.0, Pes: 99
# Valor: -890.5, Pes: 101
# Valor: 97.0, Pes: 94
# Valor: 104.0, Pes: 98
# Valor: 100.0, Pes: 93
# Valor: 106.0, Pes: 100
# Valor: 92.5, Pes: 89
# Valor: 97.5, Pes: 90
# Valor: -4892.5, Pes: 105
# Valor: 96.0, Pes: 93
# Valor: -894.0, Pes: 101
# Valor: 104.5, Pes: 96
# Valor: 103.0, Pes: 96
# Generació: 13: 108.5
# Individu: [10, 10, 0, 6, 3, 5, 7, 8, 9, 3, 10, 8, 8]
# Valor: 102.0, Pes: 95
# Valor: 103.0, Pes: 97
# Valor: 104.0, Pes: 98
# Valor: 105.0, Pes: 95
# Valor: 100.0, Pes: 96
# Valor: 103.0, Pes: 99
# Valor: 90.0, Pes: 80
# Valor: -4889.5, Pes: 105
# Valor: 102.0, Pes: 95
# Valor: 104.0, Pes: 100
# Valor: -2888.5, Pes: 103
# Valor: 97.5, Pes: 90
# Valor: 103.0, Pes: 95
# Valor: 104.5, Pes: 98
# Valor: 95.5, Pes: 87
# Valor: -7889.5, Pes: 108
# Valor: 96.0, Pes: 90
# Valor: 105.0, Pes: 99
# Valor: 100.0, Pes: 95
# Valor: -1892.5, Pes: 102
# Valor: 99.5, Pes: 91
# Valor: -3891.0, Pes: 104
# Valor: 101.0, Pes: 97
# Valor: 101.5, Pes: 99
# Valor: 98.0, Pes: 95
# Valor: 103.0, Pes: 98
# Valor: 103.5, Pes: 95
# Valor: 103.0, Pes: 97
# Valor: 84.0, Pes: 80
# Valor: 98.5, Pes: 92
# Valor: 104.0, Pes: 98
# Valor: 98.5, Pes: 90
# Valor: 104.5, Pes: 98
# Valor: 99.5, Pes: 93
# Valor: 104.0, Pes: 99
# Valor: 100.0, Pes: 96
# Valor: 101.0, Pes: 93
# Valor: 107.5, Pes: 100
# Valor: 105.0, Pes: 99
# Valor: 97.0, Pes: 91
# Valor: -1891.5, Pes: 102
# Valor: 107.0, Pes: 99
# Valor: -1889.5, Pes: 102
# Valor: 95.5, Pes: 94
# Valor: -5889.0, Pes: 106
# Valor: 89.0, Pes: 82
# Valor: 96.5, Pes: 90
# Valor: 107.0, Pes: 99
# Valor: -894.5, Pes: 101
# Valor: 94.0, Pes: 88
# Valor: 102.5, Pes: 98
# Valor: -2890.5, Pes: 103
# Valor: 106.0, Pes: 100
# Valor: 97.5, Pes: 96
# Valor: 98.0, Pes: 93
# Valor: 104.0, Pes: 98
# Valor: 97.5, Pes: 91
# Valor: 104.0, Pes: 98
# Valor: 104.0, Pes: 97
# Valor: 103.0, Pes: 98
# Valor: 95.5, Pes: 94
# Valor: 104.0, Pes: 98
# Valor: 94.0, Pes: 88
# Valor: -1892.0, Pes: 102
# Valor: 99.0, Pes: 93
# Valor: 101.0, Pes: 95
# Valor: 104.0, Pes: 98
# Valor: 101.0, Pes: 97
# Valor: 97.5, Pes: 88
# Valor: 99.5, Pes: 98
# Valor: 101.5, Pes: 96
# Valor: 103.5, Pes: 95
# Valor: 103.5, Pes: 97
# Valor: 102.0, Pes: 96
# Valor: 101.0, Pes: 95
# Valor: -4890.0, Pes: 105
# Valor: -896.0, Pes: 101
# Valor: 95.0, Pes: 91
# Generació: 14: 108.5
# Individu: [10, 10, 0, 6, 3, 5, 7, 8, 9, 3, 10, 8, 8]
# Valor: 101.0, Pes: 95
# Valor: 91.5, Pes: 88
# Valor: 92.5, Pes: 83
# Valor: -11886.0, Pes: 112
# Valor: 104.5, Pes: 98
# Valor: 97.0, Pes: 91
# Valor: 103.0, Pes: 96
# Valor: 105.5, Pes: 99
# Valor: 100.0, Pes: 95
# Valor: -892.5, Pes: 101
# Valor: 101.0, Pes: 97
# Valor: 101.5, Pes: 95
# Valor: 100.0, Pes: 90
# Valor: 108.5, Pes: 100
# Valor: 100.0, Pes: 95
# Valor: -893.0, Pes: 101
# Valor: 106.5, Pes: 98
# Valor: 95.0, Pes: 92
# Valor: 106.0, Pes: 99
# Valor: 102.0, Pes: 96
# Valor: 105.5, Pes: 99
# Valor: 97.0, Pes: 91
# Valor: 100.5, Pes: 94
# Valor: 108.5, Pes: 100
# Valor: 104.0, Pes: 98
# Valor: 101.0, Pes: 97
# Valor: 99.0, Pes: 92
# Valor: -1897.5, Pes: 102
# Valor: 100.0, Pes: 94
# Valor: -4893.5, Pes: 105
# Valor: 100.0, Pes: 93
# Valor: 105.0, Pes: 99
# Valor: 100.5, Pes: 94
# Valor: 107.5, Pes: 100
# Valor: 101.5, Pes: 96
# Valor: 106.0, Pes: 99
# Valor: 105.0, Pes: 99
# Valor: 101.0, Pes: 93
# Valor: 104.0, Pes: 98
# Valor: 104.5, Pes: 96
# Valor: 107.5, Pes: 98
# Valor: 102.5, Pes: 97
# Valor: -1892.5, Pes: 102
# Valor: -893.0, Pes: 101
# Valor: 102.5, Pes: 94
# Valor: -7886.5, Pes: 108
# Valor: 100.5, Pes: 97
# Valor: 96.0, Pes: 92
# Valor: 100.5, Pes: 92
# Valor: -892.5, Pes: 101
# Valor: -4891.0, Pes: 105
# Valor: 103.5, Pes: 95
# Valor: 101.0, Pes: 97
# Valor: 100.0, Pes: 94
# Valor: 100.5, Pes: 91
# Valor: 87.5, Pes: 84
# Valor: 101.0, Pes: 95
# Valor: 105.0, Pes: 100
# Valor: 105.0, Pes: 98
# Valor: 95.0, Pes: 93
# Valor: -2891.0, Pes: 103
# Valor: 100.0, Pes: 94
# Valor: 94.0, Pes: 92
# Valor: 103.5, Pes: 95
# Valor: -891.0, Pes: 101
# Valor: 98.0, Pes: 92
# Valor: -2890.0, Pes: 103
# Valor: 100.0, Pes: 93
# Valor: 97.0, Pes: 95
# Valor: 104.5, Pes: 96
# Valor: 104.0, Pes: 97
# Valor: 106.5, Pes: 99
# Valor: 109.0, Pes: 100
# Valor: 97.0, Pes: 91
# Generació: 15: 109.0
# Individu: [8, 10, 0, 10, 0, 7, 5, 7, 8, 7, 10, 10, 8]
# Valor: 104.0, Pes: 97
# Valor: 107.0, Pes: 100
# Valor: 101.0, Pes: 95
# Valor: 88.5, Pes: 85
# Valor: 108.5, Pes: 100
# Valor: 105.0, Pes: 99
# Valor: 106.0, Pes: 99
# Valor: 105.0, Pes: 99
# Valor: 106.5, Pes: 98
# Valor: 103.0, Pes: 99
# Valor: 105.5, Pes: 97
# Valor: -2893.0, Pes: 103
# Valor: -2888.5, Pes: 103
# Valor: 106.0, Pes: 97
# Valor: 104.0, Pes: 97
# Valor: -893.0, Pes: 101
# Valor: 105.0, Pes: 100
# Valor: 106.0, Pes: 99
# Valor: 103.5, Pes: 95
# Valor: -1891.0, Pes: 102
# Valor: 97.5, Pes: 95
# Valor: 101.0, Pes: 93
# Valor: 101.5, Pes: 95
# Valor: -3891.0, Pes: 104
# Valor: 95.0, Pes: 88
# Valor: -5889.0, Pes: 106
# Valor: 96.0, Pes: 90
# Valor: 104.0, Pes: 98
# Valor: 105.0, Pes: 98
# Valor: 103.5, Pes: 98
# Valor: 101.5, Pes: 93
# Valor: -893.0, Pes: 101
# Valor: 106.0, Pes: 100
# Valor: 103.5, Pes: 95
# Valor: 101.5, Pes: 93
# Valor: 98.0, Pes: 95
# Valor: 102.0, Pes: 98
# Valor: 99.0, Pes: 93
# Valor: 107.5, Pes: 98
# Valor: 103.5, Pes: 95
# Valor: 101.5, Pes: 96
# Valor: 101.0, Pes: 97
# Valor: 104.0, Pes: 98
# Valor: 100.0, Pes: 96
# Valor: 103.0, Pes: 98
# Valor: 100.0, Pes: 94
# Valor: 102.0, Pes: 96
# Valor: 100.0, Pes: 94
# Valor: 104.0, Pes: 98
# Valor: 103.5, Pes: 98
# Valor: 98.5, Pes: 93
# Valor: 104.0, Pes: 100
# Valor: 104.0, Pes: 97
# Valor: 107.0, Pes: 100
# Valor: 100.0, Pes: 95
# Valor: 109.0, Pes: 100
# Valor: -2890.5, Pes: 103
# Valor: 103.5, Pes: 95
# Valor: 105.5, Pes: 97
# Valor: -1891.5, Pes: 102
# Valor: 104.0, Pes: 97
# Valor: 108.5, Pes: 100
# Valor: 98.5, Pes: 91
# Valor: -8889.5, Pes: 109
# Valor: 96.5, Pes: 90
# Valor: -2895.5, Pes: 103
# Valor: -4891.0, Pes: 105
# Valor: 100.0, Pes: 94
# Valor: 99.0, Pes: 92
# Valor: 103.0, Pes: 95
# Valor: -2894.0, Pes: 103
# Valor: 97.5, Pes: 89
# Generació: 16: 109.0
# Individu: [8, 10, 0, 10, 0, 7, 5, 7, 8, 7, 10, 10, 8]
# Valor: 103.5, Pes: 95
# Valor: -2890.5, Pes: 103
# Valor: 96.5, Pes: 88
# Valor: 101.5, Pes: 95
# Valor: 104.0, Pes: 97
# Valor: -2890.0, Pes: 103
# Valor: -8884.5, Pes: 109
# Valor: 91.5, Pes: 83
# Valor: -890.5, Pes: 101
# Valor: 97.5, Pes: 89
# Valor: 107.5, Pes: 99
# Valor: 103.5, Pes: 96
# Valor: 107.0, Pes: 100
# Valor: 103.0, Pes: 97
# Valor: 104.5, Pes: 98
# Valor: -889.5, Pes: 101
# Valor: 101.0, Pes: 95
# Valor: 103.0, Pes: 98
# Valor: 101.5, Pes: 93
# Valor: 106.0, Pes: 97
# Valor: 100.0, Pes: 94
# Valor: 101.5, Pes: 93
# Valor: 103.0, Pes: 97
# Valor: 106.5, Pes: 98
# Valor: 104.0, Pes: 97
# Valor: 106.0, Pes: 100
# Valor: 104.0, Pes: 97
# Valor: 105.0, Pes: 99
# Valor: -5888.0, Pes: 106
# Valor: 97.0, Pes: 90
# Valor: 103.0, Pes: 94
# Valor: -1892.0, Pes: 102
# Valor: -2891.0, Pes: 103
# Valor: 93.5, Pes: 85
# Valor: 93.5, Pes: 85
# Valor: -10887.5, Pes: 111
# Valor: 102.0, Pes: 96
# Valor: 103.5, Pes: 95
# Valor: -893.0, Pes: 101
# Valor: 93.0, Pes: 86
# Valor: 101.5, Pes: 94
# Valor: 101.0, Pes: 94
# Valor: -2892.0, Pes: 103
# Valor: 97.0, Pes: 93
# Valor: 101.5, Pes: 95
# Valor: 105.0, Pes: 99
# Valor: 102.0, Pes: 95
# Valor: 108.0, Pes: 99
# Valor: 100.5, Pes: 92
# Valor: 102.0, Pes: 98
# Valor: 105.5, Pes: 99
# Valor: -892.0, Pes: 101
# Valor: 102.5, Pes: 97
# Valor: 104.5, Pes: 96
# Valor: -3891.0, Pes: 104
# Valor: 102.0, Pes: 93
# Valor: 101.0, Pes: 95
# Valor: 103.5, Pes: 97
# Valor: 93.5, Pes: 88
# Valor: 105.0, Pes: 99
# Valor: 108.5, Pes: 100
# Valor: 105.0, Pes: 98
# Valor: 102.0, Pes: 96
# Valor: 103.0, Pes: 97
# Valor: 106.0, Pes: 99
# Valor: 106.0, Pes: 99
# Valor: 102.0, Pes: 96
# Valor: -895.0, Pes: 101
# Valor: 99.0, Pes: 92
# Valor: 104.0, Pes: 98
# Valor: 102.0, Pes: 96
# Valor: 105.5, Pes: 97
# Generació: 17: 109.0
# Individu: [8, 10, 0, 10, 0, 7, 5, 7, 8, 7, 10, 10, 8]
# Valor: 100.5, Pes: 94
# Valor: -2888.0, Pes: 103
# Valor: 101.0, Pes: 95
# Valor: 105.5, Pes: 97
# Valor: 104.5, Pes: 98
# Valor: 101.5, Pes: 95
# Valor: 104.5, Pes: 98
# Valor: 101.5, Pes: 95
# Valor: 100.0, Pes: 94
# Valor: -1891.5, Pes: 102
# Valor: 104.0, Pes: 99
# Valor: 102.0, Pes: 93
# Valor: 100.0, Pes: 93
# Valor: -2891.0, Pes: 103
# Valor: -1893.0, Pes: 102
# Valor: 102.5, Pes: 94
# Valor: -892.0, Pes: 101
# Valor: 99.5, Pes: 96
# Valor: -2892.0, Pes: 103
# Valor: 101.0, Pes: 95
# Valor: -894.0, Pes: 101
# Valor: 102.0, Pes: 96
# Valor: -5889.0, Pes: 106
# Valor: -12883.5, Pes: 113
# Valor: 98.0, Pes: 89
# Valor: -7885.5, Pes: 108
# Valor: 105.0, Pes: 98
# Valor: 101.5, Pes: 95
# Valor: 96.5, Pes: 88
# Valor: -893.5, Pes: 101
# Valor: -1891.5, Pes: 102
# Valor: 102.0, Pes: 94
# Valor: 104.5, Pes: 98
# Valor: -894.5, Pes: 101
# Valor: 108.0, Pes: 99
# Valor: 105.0, Pes: 100
# Valor: 103.5, Pes: 95
# Valor: 103.5, Pes: 95
# Valor: 101.5, Pes: 93
# Valor: 105.0, Pes: 100
# Valor: 101.5, Pes: 95
# Valor: 101.0, Pes: 92
# Valor: -893.5, Pes: 101
# Valor: 107.0, Pes: 99
# Valor: 105.0, Pes: 100
# Valor: 101.0, Pes: 95
# Valor: 104.0, Pes: 97
# Valor: 104.0, Pes: 97
# Valor: 106.0, Pes: 100
# Valor: 105.0, Pes: 98
# Valor: 108.5, Pes: 100
# Valor: 90.5, Pes: 82
# Valor: 105.0, Pes: 99
# Valor: 103.0, Pes: 97
# Valor: 98.5, Pes: 93
# Valor: 96.0, Pes: 89
# Valor: 106.5, Pes: 99
# Valor: 102.0, Pes: 94
# Valor: 104.0, Pes: 97
# Valor: 105.0, Pes: 98
# Valor: -889.5, Pes: 101
# Valor: 103.5, Pes: 97
# Valor: -1892.0, Pes: 102
# Valor: 104.0, Pes: 95
# Valor: 103.5, Pes: 95
# Valor: 103.5, Pes: 95
# Valor: 100.5, Pes: 92
# Valor: 105.0, Pes: 96
# Valor: 104.0, Pes: 97
# Valor: 103.0, Pes: 97
# Valor: 105.0, Pes: 99
# Valor: 106.0, Pes: 99
# Valor: 97.5, Pes: 89
# Valor: 99.0, Pes: 90
# Valor: 102.0, Pes: 96
# Valor: 105.0, Pes: 99
# Valor: -2890.5, Pes: 103
# Valor: 100.5, Pes: 92
# Generació: 18: 109.0
# Individu: [8, 10, 0, 10, 0, 7, 5, 7, 8, 7, 10, 10, 8]
# Valor: 105.5, Pes: 97
# Valor: 104.0, Pes: 97
# Valor: -2891.0, Pes: 103
# Valor: 104.0, Pes: 96
# Valor: 105.0, Pes: 98
# Valor: 105.5, Pes: 98
# Valor: 105.0, Pes: 98
# Valor: 101.5, Pes: 95
# Valor: 96.5, Pes: 90
# Valor: -5887.5, Pes: 106
# Valor: 100.5, Pes: 93
# Valor: -2891.0, Pes: 103
# Valor: 105.0, Pes: 99
# Valor: 103.0, Pes: 96
# Valor: 102.0, Pes: 93
# Valor: 104.5, Pes: 96
# Valor: 106.0, Pes: 98
# Valor: 104.5, Pes: 98
# Valor: 101.0, Pes: 92
# Valor: -2891.0, Pes: 103
# Valor: 104.5, Pes: 96
# Valor: 108.5, Pes: 100
# Valor: -1892.0, Pes: 102
# Valor: 99.0, Pes: 93
# Valor: 103.5, Pes: 97
# Valor: 103.5, Pes: 95
# Valor: 104.0, Pes: 95
# Valor: 104.5, Pes: 98
# Valor: 104.0, Pes: 97
# Valor: 104.0, Pes: 97
# Valor: 104.5, Pes: 96
# Valor: 105.5, Pes: 99
# Valor: 107.5, Pes: 99
# Valor: 101.0, Pes: 92
# Valor: 106.0, Pes: 100
# Valor: 100.0, Pes: 94
# Valor: 104.0, Pes: 98
# Valor: 101.0, Pes: 94
# Valor: 102.5, Pes: 93
# Valor: 106.0, Pes: 100
# Valor: -1892.5, Pes: 102
# Valor: 101.0, Pes: 94
# Valor: 102.5, Pes: 96
# Valor: -891.5, Pes: 101
# Valor: -891.5, Pes: 101
# Valor: 102.5, Pes: 96
# Valor: -4888.0, Pes: 105
# Valor: 98.5, Pes: 89
# Valor: 105.0, Pes: 99
# Valor: 88.5, Pes: 80
# Valor: 105.0, Pes: 96
# Valor: 105.0, Pes: 100
# Valor: 102.5, Pes: 96
# Valor: 107.0, Pes: 100
# Valor: 98.0, Pes: 91
# Valor: -6888.0, Pes: 107
# Valor: 102.5, Pes: 98
# Valor: 103.0, Pes: 96
# Valor: 100.0, Pes: 91
# Valor: 107.5, Pes: 99
# Valor: 105.0, Pes: 98
# Valor: 101.0, Pes: 95
# Valor: 107.0, Pes: 99
# Valor: -893.5, Pes: 101
# Valor: -894.0, Pes: 101
# Valor: 104.0, Pes: 99
# Valor: 102.0, Pes: 96
# Valor: 102.5, Pes: 94
# Valor: 98.0, Pes: 91
# Valor: -892.5, Pes: 101
# Valor: 103.5, Pes: 99
# Valor: 106.5, Pes: 97
# Valor: 102.0, Pes: 97
# Valor: -890.5, Pes: 101
# Valor: 103.5, Pes: 96
# Valor: -893.5, Pes: 101
# Valor: 104.0, Pes: 96
# Valor: 103.5, Pes: 95
# Valor: 106.0, Pes: 100
# Valor: 102.5, Pes: 94
# Valor: -2888.5, Pes: 103
# Valor: 93.5, Pes: 88
# Valor: -1890.5, Pes: 102
# Valor: 100.0, Pes: 92
# Generació: 19: 108.5
# Individu: [9, 10, 2, 10, 0, 7, 5, 8, 8, 7, 9, 7, 8]
# Valor: 100.0, Pes: 92
# Valor: -892.0, Pes: 101
# Valor: 101.5, Pes: 95
# Valor: 105.5, Pes: 100
# Valor: 100.5, Pes: 91
# Valor: 103.0, Pes: 97
# Valor: -2892.0, Pes: 103
# Valor: 100.0, Pes: 93
# Valor: -1889.5, Pes: 102
# Valor: 102.5, Pes: 94
# Valor: 107.0, Pes: 100
# Valor: 104.0, Pes: 97
# Valor: 105.0, Pes: 99
# Valor: -1890.5, Pes: 102
# Valor: 105.5, Pes: 96
# Valor: 103.5, Pes: 95
# Valor: 107.5, Pes: 99
# Valor: 96.5, Pes: 88
# Valor: 108.0, Pes: 98
# Valor: -1892.0, Pes: 102
# Valor: 102.0, Pes: 95
# Valor: 107.0, Pes: 100
# Valor: 104.0, Pes: 95
# Valor: 102.0, Pes: 96
# Valor: 84.0, Pes: 80
# Valor: 103.5, Pes: 95
# Valor: 105.0, Pes: 100
# Valor: 102.0, Pes: 96
# Valor: -2890.0, Pes: 103
# Valor: 100.0, Pes: 93
# Valor: 102.0, Pes: 96
# Valor: 104.0, Pes: 95
# Valor: 105.0, Pes: 99
# Valor: 100.0, Pes: 94
# Valor: 97.5, Pes: 92
# Valor: 104.5, Pes: 96
# Valor: 102.0, Pes: 93
# Valor: 103.5, Pes: 95
# Valor: 104.0, Pes: 99
# Valor: 106.0, Pes: 100
# Valor: 88.5, Pes: 86
# Valor: 102.5, Pes: 94
# Valor: 102.5, Pes: 94
# Valor: 100.0, Pes: 94
# Valor: 106.5, Pes: 98
# Valor: 94.0, Pes: 87
# Valor: 103.0, Pes: 96
# Valor: -1892.5, Pes: 102
# Valor: 104.0, Pes: 97
# Valor: 105.0, Pes: 96
# Valor: 94.5, Pes: 86
# Valor: 98.5, Pes: 93
# Valor: 104.0, Pes: 98
# Valor: 101.0, Pes: 95
# Valor: 105.0, Pes: 96
# Valor: 103.5, Pes: 95
# Valor: 101.5, Pes: 95
# Valor: 106.0, Pes: 100
# Valor: 103.0, Pes: 97
# Valor: -2891.5, Pes: 103
# Valor: 104.5, Pes: 96
# Valor: 106.0, Pes: 99
# Valor: 98.5, Pes: 92
# Valor: -1890.0, Pes: 102
# Valor: 106.5, Pes: 98
# Valor: 105.0, Pes: 96
# Valor: 108.5, Pes: 100
# Valor: -2891.0, Pes: 103
# Valor: -2891.0, Pes: 103
# Valor: 102.0, Pes: 95
# Valor: 106.0, Pes: 99
# Valor: 103.0, Pes: 97
# Valor: 105.5, Pes: 97
# Valor: 108.5, Pes: 100
# Valor: -2891.0, Pes: 103
# Valor: 103.5, Pes: 95
# Valor: 104.5, Pes: 96
# Valor: 106.0, Pes: 97
# Valor: 101.5, Pes: 93
# Valor: 99.0, Pes: 92
# Valor: 95.0, Pes: 91
# Valor: 103.5, Pes: 95
# Valor: 103.0, Pes: 96
# Valor: 105.0, Pes: 98
# Valor: 97.0, Pes: 88
# Valor: 105.0, Pes: 100
# Valor: 102.0, Pes: 95
# Valor: -2890.0, Pes: 103
# Valor: -6887.0, Pes: 107
# Valor: 96.0, Pes: 87
# Generació: 20: 108.5
# Individu: [9, 10, 2, 10, 0, 7, 5, 8, 8, 7, 9, 7, 8]
# Valor: 102.5, Pes: 94
# Valor: 100.0, Pes: 94
# Valor: 103.0, Pes: 95
# Valor: 105.5, Pes: 96
# Valor: 103.0, Pes: 97
# Valor: 100.5, Pes: 92
# Valor: 105.5, Pes: 97
# Valor: 105.5, Pes: 97
# Valor: 107.0, Pes: 99
# Valor: 103.5, Pes: 98
# Valor: 105.0, Pes: 96
# Valor: 105.0, Pes: 96
# Valor: 104.5, Pes: 96
# Valor: 102.5, Pes: 94
# Valor: 98.0, Pes: 91
# Valor: 106.0, Pes: 99
# Valor: 101.5, Pes: 93
# Valor: -1892.0, Pes: 102
# Valor: 103.5, Pes: 95
# Valor: 106.0, Pes: 100
# Valor: 106.0, Pes: 99
# Valor: -1892.0, Pes: 102
# Valor: 102.0, Pes: 95
# Valor: 101.5, Pes: 93
# Valor: 101.0, Pes: 93
# Valor: -2892.0, Pes: 103
# Valor: -2891.0, Pes: 103
# Valor: 107.0, Pes: 100
# Valor: 104.5, Pes: 96
# Valor: 103.0, Pes: 97
# Valor: 106.5, Pes: 98
# Valor: 103.5, Pes: 94
# Valor: -3890.0, Pes: 104
# Valor: 94.5, Pes: 86
# Valor: 108.5, Pes: 100
# Valor: 97.5, Pes: 89
# Valor: 98.5, Pes: 90
# Valor: 106.0, Pes: 98
# Valor: -4889.0, Pes: 105
# Valor: 96.5, Pes: 88
# Valor: 104.0, Pes: 97
# Valor: 106.0, Pes: 99
# Valor: 100.0, Pes: 93
# Valor: 105.0, Pes: 96
# Valor: 102.0, Pes: 93
# Valor: 108.5, Pes: 100
# Valor: 103.0, Pes: 94
# Valor: 107.5, Pes: 99
# Valor: 100.0, Pes: 92
# Valor: -2891.0, Pes: 103
# Valor: 106.0, Pes: 99
# Valor: 106.0, Pes: 97
# Valor: 93.5, Pes: 84
# Valor: 103.0, Pes: 96
# Valor: 106.0, Pes: 99
# Valor: -891.0, Pes: 101
# Valor: 105.5, Pes: 97
# Valor: 104.5, Pes: 96
# Valor: 102.0, Pes: 96
# Valor: 108.5, Pes: 100
# Valor: -893.0, Pes: 101
# Valor: 104.5, Pes: 95
# Valor: 109.0, Pes: 99
# Valor: -2890.0, Pes: 103
# Valor: 108.5, Pes: 100
# Valor: 96.0, Pes: 87
# Valor: 107.0, Pes: 100
# Valor: 105.0, Pes: 99
# Valor: 106.0, Pes: 99
# Valor: 105.0, Pes: 98
# Valor: 104.5, Pes: 96
# Valor: 107.0, Pes: 99
# Valor: 105.0, Pes: 96
# Valor: 106.5, Pes: 98
# Valor: 101.0, Pes: 94
# Valor: 108.0, Pes: 99
# Valor: 105.5, Pes: 97
# Valor: 107.0, Pes: 98
# Valor: 105.5, Pes: 96
# Valor: 102.0, Pes: 94
# Valor: 95.5, Pes: 87
# Valor: -6888.0, Pes: 107
# Generació: 21: 109.0
# Individu: [10, 10, 0, 10, 0, 7, 5, 8, 8, 7, 9, 7, 8]
# Valor: 107.5, Pes: 99
# Valor: 102.0, Pes: 95
# Valor: -2888.5, Pes: 103
# Valor: 105.5, Pes: 97
# Valor: 102.0, Pes: 93
# Valor: -2891.0, Pes: 103
# Valor: 102.0, Pes: 94
# Valor: 103.0, Pes: 95
# Valor: 107.0, Pes: 100
# Valor: 106.0, Pes: 98
# Valor: 102.0, Pes: 95
# Valor: -1889.5, Pes: 102
# Valor: 107.0, Pes: 100
# Valor: 105.0, Pes: 96
# Valor: 103.5, Pes: 98
# Valor: 98.5, Pes: 89
# Valor: 99.0, Pes: 92
# Valor: -4889.0, Pes: 105
# Valor: 107.0, Pes: 98
# Valor: 105.0, Pes: 97
# Valor: 96.5, Pes: 88
# Valor: -2890.0, Pes: 103
# Valor: 102.5, Pes: 94
# Valor: 106.0, Pes: 98
# Valor: 99.0, Pes: 95
# Valor: 100.5, Pes: 92
# Valor: 104.0, Pes: 97
# Valor: 107.5, Pes: 99
# Valor: 106.5, Pes: 98
# Valor: 102.0, Pes: 95
# Valor: 103.0, Pes: 96
# Valor: 108.0, Pes: 99
# Valor: 105.5, Pes: 96
# Valor: 106.0, Pes: 99
# Valor: -7886.0, Pes: 108
# Valor: 89.5, Pes: 81
# Valor: 103.0, Pes: 96
# Valor: 108.5, Pes: 100
# Valor: 105.0, Pes: 96
# Valor: 105.0, Pes: 95
# Valor: 106.0, Pes: 99
# Valor: 105.0, Pes: 98
# Valor: 105.5, Pes: 97
# Valor: 106.0, Pes: 98
# Valor: 103.5, Pes: 94
# Valor: -4888.0, Pes: 105
# Valor: 102.0, Pes: 94
# Valor: 104.0, Pes: 98
# Valor: 104.5, Pes: 96
# Valor: 103.0, Pes: 94
# Valor: 108.5, Pes: 100
# Valor: 106.5, Pes: 98
# Valor: 106.0, Pes: 97
# Valor: 109.0, Pes: 99
# Valor: 103.0, Pes: 96
# Valor: 108.0, Pes: 100
# Valor: 103.0, Pes: 96
# Valor: 104.0, Pes: 97
# Valor: -1889.0, Pes: 102
# Valor: 102.0, Pes: 93
# Valor: 105.0, Pes: 95
# Valor: 105.5, Pes: 97
# Valor: 92.0, Pes: 88
# Valor: 104.5, Pes: 96
# Valor: 103.5, Pes: 95
# Valor: 105.5, Pes: 97
# Valor: 108.5, Pes: 100
# Valor: 105.5, Pes: 97
# Valor: 95.0, Pes: 91
# Valor: 98.0, Pes: 91
# Valor: 107.0, Pes: 100
# Valor: 107.5, Pes: 99
# Valor: 105.0, Pes: 98
# Valor: 105.5, Pes: 96
# Valor: 108.5, Pes: 100
# Valor: 105.0, Pes: 98
# Valor: 106.0, Pes: 100
# Valor: 104.5, Pes: 96
# Valor: 100.5, Pes: 91
# Valor: 107.0, Pes: 100
# Valor: 106.5, Pes: 99
# Valor: 104.5, Pes: 95
# Valor: 98.0, Pes: 92
# Valor: 98.5, Pes: 89
# Generació: 22: 109.0
# Individu: [10, 10, 0, 10, 0, 7, 5, 8, 8, 7, 9, 7, 8]
# Valor: -7885.0, Pes: 108
# Valor: 97.5, Pes: 88
# Valor: 107.5, Pes: 99
# Valor: 105.5, Pes: 97
# Valor: -1889.5, Pes: 102
# Valor: 95.5, Pes: 86
# Valor: 102.0, Pes: 95
# Valor: -1891.0, Pes: 102
# Valor: 104.5, Pes: 95
# Valor: 106.0, Pes: 99
# Valor: 106.0, Pes: 96
# Valor: 108.5, Pes: 100
# Valor: -1892.0, Pes: 102
# Valor: 103.5, Pes: 95
# Valor: -892.0, Pes: 101
# Valor: 102.0, Pes: 93
# Valor: 107.0, Pes: 100
# Valor: -2890.0, Pes: 103
# Valor: 107.0, Pes: 99
# Valor: 106.0, Pes: 99
# Valor: 107.5, Pes: 99
# Valor: 107.0, Pes: 98
# Valor: 107.0, Pes: 98
# Valor: 107.5, Pes: 99
# Valor: 105.0, Pes: 97
# Valor: 108.0, Pes: 100
# Valor: 109.0, Pes: 99
# Valor: 104.5, Pes: 96
# Valor: 104.5, Pes: 97
# Valor: 107.5, Pes: 98
# Valor: 101.5, Pes: 92
# Valor: 105.0, Pes: 98
# Valor: 104.5, Pes: 96
# Valor: -2890.0, Pes: 103
# Valor: 106.5, Pes: 98
# Valor: -890.5, Pes: 101
# Valor: 102.5, Pes: 94
# Valor: -3889.0, Pes: 104
# Valor: 104.5, Pes: 96
# Valor: 107.0, Pes: 100
# Valor: 107.0, Pes: 99
# Valor: 104.0, Pes: 95
# Valor: 104.5, Pes: 95
# Valor: 96.0, Pes: 92
# Valor: 106.0, Pes: 99
# Valor: 108.0, Pes: 99
# Valor: 103.0, Pes: 96
# Valor: 105.5, Pes: 96
# Valor: 107.0, Pes: 100
# Valor: 108.5, Pes: 100
# Valor: 108.0, Pes: 100
# Valor: 107.0, Pes: 98
# Valor: -1891.0, Pes: 102
# Valor: 105.0, Pes: 96
# Valor: 102.0, Pes: 93
# Valor: 103.0, Pes: 96
# Valor: 107.0, Pes: 100
# Valor: 106.0, Pes: 99
# Valor: 100.5, Pes: 91
# Valor: 107.5, Pes: 99
# Valor: 103.0, Pes: 95
# Valor: 107.0, Pes: 100
# Valor: 103.0, Pes: 94
# Valor: -1891.0, Pes: 102
# Valor: 108.0, Pes: 99
# Valor: 103.0, Pes: 96
# Valor: 106.0, Pes: 99
# Valor: -2890.0, Pes: 103
# Generació: 23: 109.0
# Individu: [10, 10, 0, 10, 0, 7, 5, 8, 8, 7, 9, 7, 8]
# Valor: 108.5, Pes: 100
# Valor: 107.0, Pes: 100
# Valor: -5886.5, Pes: 106
# Valor: 98.0, Pes: 90
# Valor: 107.5, Pes: 98
# Valor: 109.0, Pes: 99
# Valor: -3889.0, Pes: 104
# Valor: 104.0, Pes: 96
# Valor: 106.5, Pes: 97
# Valor: 107.0, Pes: 100
# Valor: 105.0, Pes: 96
# Valor: -2890.0, Pes: 103
# Valor: -890.0, Pes: 101
# Valor: 105.0, Pes: 98
# Valor: -1889.5, Pes: 102
# Valor: 103.0, Pes: 96
# Valor: 98.5, Pes: 89
# Valor: 106.0, Pes: 99
# Valor: 106.0, Pes: 98
# Valor: 108.5, Pes: 100
# Valor: -2890.0, Pes: 103
# Valor: 106.0, Pes: 96
# Valor: 106.0, Pes: 97
# Valor: 102.5, Pes: 94
# Valor: -889.5, Pes: 101
# Valor: 103.5, Pes: 95
# Valor: 107.0, Pes: 100
# Valor: 107.0, Pes: 100
# Valor: -6886.0, Pes: 107
# Valor: 96.0, Pes: 87
# Valor: 104.5, Pes: 96
# Valor: 108.5, Pes: 100
# Valor: 109.0, Pes: 99
# Valor: 104.5, Pes: 96
# Valor: 107.0, Pes: 100
# Valor: 107.0, Pes: 98
# Valor: 105.0, Pes: 98
# Valor: 106.5, Pes: 97
# Valor: 102.0, Pes: 94
# Valor: -890.5, Pes: 101
# Valor: 107.5, Pes: 98
# Valor: 109.0, Pes: 100
# Valor: 107.0, Pes: 98
# Valor: 107.0, Pes: 98
# Valor: 107.5, Pes: 99
# Valor: 106.0, Pes: 99
# Valor: 104.5, Pes: 99
# Valor: 107.5, Pes: 99
# Valor: 107.0, Pes: 98
# Valor: 108.0, Pes: 100
# Valor: 107.5, Pes: 98
# Valor: 106.5, Pes: 99
# Valor: 109.0, Pes: 100
# Valor: 100.5, Pes: 91
# Valor: 107.0, Pes: 98
# Valor: 107.5, Pes: 99
# Valor: 99.5, Pes: 90
# Valor: -9884.0, Pes: 110
# Valor: -3887.5, Pes: 104
# Valor: 103.0, Pes: 96
# Valor: 106.5, Pes: 98
# Valor: 107.0, Pes: 100
# Valor: 108.5, Pes: 100
# Valor: 104.0, Pes: 97
# Valor: -1899.0, Pes: 102
# Valor: 106.5, Pes: 98
# Valor: 106.0, Pes: 99
# Valor: 101.5, Pes: 92
# Valor: 104.0, Pes: 97
# Valor: 106.5, Pes: 98
# Valor: 104.0, Pes: 96
# Valor: 106.5, Pes: 98
# Valor: -1891.0, Pes: 102
# Valor: 104.0, Pes: 95
# Valor: 108.5, Pes: 100
# Valor: 108.5, Pes: 100
# Valor: 107.0, Pes: 99
# Valor: 108.0, Pes: 100
# Valor: 106.0, Pes: 98
# Valor: 107.5, Pes: 99
# Valor: 109.5, Pes: 100
# Valor: 101.5, Pes: 95
# Generació: 24: 109.5
# Individu: [9, 10, 0, 10, 0, 7, 5, 8, 8, 7, 10, 8, 8]
# Valor: 106.5, Pes: 98
# Valor: 110.0, Pes: 100
# Valor: 107.5, Pes: 98
# Valor: 109.0, Pes: 99
# Valor: 106.0, Pes: 98
# Valor: 108.5, Pes: 100
# Valor: 108.0, Pes: 100
# Valor: 106.5, Pes: 97
# Valor: 108.5, Pes: 100
# Valor: 106.0, Pes: 99
# Valor: 105.0, Pes: 96
# Valor: 107.5, Pes: 98
# Valor: 102.5, Pes: 96
# Valor: 105.0, Pes: 95
# Valor: 103.0, Pes: 94
# Valor: -1890.0, Pes: 102
# Valor: 104.0, Pes: 96
# Valor: -1891.0, Pes: 102
# Valor: 107.0, Pes: 98
# Valor: 109.0, Pes: 100
# Valor: 105.0, Pes: 98
# Valor: 104.0, Pes: 97
# Valor: 107.0, Pes: 98
# Valor: 107.5, Pes: 99
# Valor: 107.0, Pes: 100
# Valor: 105.0, Pes: 95
# Valor: -5888.0, Pes: 106
# Valor: 99.5, Pes: 90
# Valor: -890.5, Pes: 101
# Valor: 105.5, Pes: 97
# Valor: 101.5, Pes: 92
# Valor: -5887.0, Pes: 106
# Valor: 105.0, Pes: 97
# Valor: 108.0, Pes: 100
# Valor: 106.0, Pes: 98
# Valor: -1891.0, Pes: 102
# Valor: -1891.0, Pes: 102
# Valor: 101.5, Pes: 96
# Valor: 102.0, Pes: 94
# Valor: -1891.0, Pes: 102
# Valor: 106.0, Pes: 99
# Valor: 107.0, Pes: 100
# Valor: 105.5, Pes: 97
# Valor: 108.0, Pes: 100
# Valor: 109.0, Pes: 99
# Valor: 108.5, Pes: 100
# Valor: 106.5, Pes: 97
# Valor: 107.5, Pes: 99
# Valor: 99.0, Pes: 92
# Valor: -3887.5, Pes: 104
# Valor: -1889.5, Pes: 102
# Valor: 103.0, Pes: 96
# Valor: -3889.0, Pes: 104
# Valor: 98.5, Pes: 91
# Valor: -1889.5, Pes: 102
# Valor: 107.0, Pes: 100
# Valor: 108.0, Pes: 98
# Valor: -890.0, Pes: 101
# Valor: 106.0, Pes: 99
# Valor: -889.5, Pes: 101
# Valor: 109.0, Pes: 100
# Valor: 104.0, Pes: 94
# Generació: 25: 110.0
# Individu: [10, 10, 0, 10, 0, 7, 5, 8, 8, 7, 9, 8, 8]
# Valor: 106.0, Pes: 98
# Valor: 108.0, Pes: 100
# Valor: -890.0, Pes: 101
# Valor: 107.5, Pes: 99
# Valor: -2888.0, Pes: 103
# Valor: 101.0, Pes: 93
# Valor: -7884.5, Pes: 108
# Valor: 99.5, Pes: 90
# Valor: 105.0, Pes: 96
# Valor: 108.5, Pes: 99
# Valor: 104.5, Pes: 95
# Valor: -4886.5, Pes: 105
# Valor: 109.0, Pes: 99
# Valor: 107.5, Pes: 98
# Valor: 108.5, Pes: 100
# Valor: 109.0, Pes: 99
# Valor: 109.0, Pes: 99
# Valor: 106.5, Pes: 97
# Valor: 103.5, Pes: 94
# Valor: -4886.5, Pes: 105
# Valor: -890.0, Pes: 101
# Valor: 107.5, Pes: 99
# Valor: 103.0, Pes: 96
# Valor: -893.0, Pes: 101
# Valor: 93.5, Pes: 84
# Valor: -4889.5, Pes: 105
# Valor: 106.5, Pes: 98
# Valor: 108.5, Pes: 100
# Valor: 108.5, Pes: 99
# Valor: 107.0, Pes: 99
# Valor: 108.0, Pes: 100
# Valor: 106.5, Pes: 97
# ...
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 108.0, Pes: 98
# Generació: 92: 110.0
# Individu: [8, 10, 0, 10, 0, 7, 5, 9, 8, 7, 9, 7, 8]
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 107.0, Pes: 97
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 105.0, Pes: 95
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -4887.5, Pes: 105
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -4887.5, Pes: 105
# Valor: -4887.5, Pes: 105
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 103.0, Pes: 93
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -4887.5, Pes: 105
# Valor: 110.0, Pes: 100
# Valor: 108.5, Pes: 99
# Valor: 110.0, Pes: 100
# Valor: 106.0, Pes: 96
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 109.0, Pes: 99
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -4887.5, Pes: 105
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -4887.5, Pes: 105
# Valor: -5887.0, Pes: 106
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Generació: 93: 110.0
# Individu: [10, 10, 0, 10, 0, 7, 5, 9, 8, 7, 9, 7, 8]
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 103.0, Pes: 93
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 109.0, Pes: 99
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -13879.5, Pes: 114
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 103.0, Pes: 93
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -13879.5, Pes: 114
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -13879.5, Pes: 114
# Generació: 94: 110.0
# Individu: [10, 10, 0, 10, 0, 7, 5, 9, 8, 7, 9, 7, 8]
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -13879.5, Pes: 114
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 98.0, Pes: 92
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 104.0, Pes: 94
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -4887.5, Pes: 105
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 101.0, Pes: 94
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 98.0, Pes: 92
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -4887.5, Pes: 105
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 104.0, Pes: 94
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -13879.5, Pes: 114
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 104.0, Pes: 94
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -4887.5, Pes: 105
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -13879.5, Pes: 114
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Generació: 95: 110.0
# Individu: [10, 10, 0, 10, 0, 7, 5, 9, 8, 7, 9, 7, 8]
# Valor: 110.0, Pes: 100
# Valor: -1888.0, Pes: 102
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -4887.5, Pes: 105
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -13879.5, Pes: 114
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -13879.5, Pes: 114
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 98.0, Pes: 92
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -13879.5, Pes: 114
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Generació: 96: 110.0
# Individu: [10, 10, 0, 10, 0, 7, 5, 9, 8, 7, 9, 7, 8]
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 108.5, Pes: 99
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 109.0, Pes: 99
# Valor: 87.5, Pes: 82
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 102.0, Pes: 92
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 103.0, Pes: 93
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -1888.0, Pes: 102
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 87.5, Pes: 82
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 108.5, Pes: 99
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 105.0, Pes: 95
# Valor: 104.0, Pes: 94
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Generació: 97: 110.0
# Individu: [10, 10, 0, 10, 0, 7, 5, 9, 8, 7, 9, 7, 8]
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -13879.5, Pes: 114
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 108.0, Pes: 98
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 104.0, Pes: 94
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -13879.5, Pes: 114
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 105.0, Pes: 95
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Generació: 98: 110.0
# Individu: [10, 10, 0, 10, 0, 7, 5, 9, 8, 7, 9, 7, 8]
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 104.0, Pes: 94
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 104.0, Pes: 94
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -9885.0, Pes: 110
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 109.0, Pes: 99
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 108.0, Pes: 98
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 105.0, Pes: 95
# Valor: 104.0, Pes: 94
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Generació: 99: 110.0
# Individu: [10, 10, 0, 10, 0, 7, 5, 9, 8, 7, 9, 7, 8]
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 102.0, Pes: 92
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -9885.0, Pes: 110
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 102.0, Pes: 92
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 105.0, Pes: 95
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 102.0, Pes: 92
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 109.0, Pes: 99
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: -9885.0, Pes: 110
# Valor: 104.0, Pes: 94
# Valor: 110.0, Pes: 100
# Valor: 109.0, Pes: 99
# Valor: 110.0, Pes: 100
# Valor: 109.0, Pes: 99
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 109.0, Pes: 99
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 110.0, Pes: 100
# Valor: 104.0, Pes: 94
# Valor: 110.0, Pes: 100

# %% [markdown]
# Una vegada executat l'algorisme genètic, podem veure quin és el millor individu que s'ha trobat.

# %%
genetic.ordenar_poblacio()
print(f'Valor: {genetic.poblacio[0].fitness}')
print(f'Pes: {sum(genetic.poblacio[0].gens[i] * PRODUCTES[i][1] for i in range(len(genetic.poblacio[0].gens)))}')
print(f'Individu: {genetic.poblacio[0].gens}')
# Out:
# Valor: 110.0
# Pes: 100
# Individu: [10, 10, 0, 10, 0, 7, 5, 9, 8, 7, 9, 7, 8]
