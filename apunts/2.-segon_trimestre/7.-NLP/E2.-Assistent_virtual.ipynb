# %% [markdown]
# # Creació d'un prototip d'assistent virtual
#
# En aquesta pràctica es proposa la creació d'un prototip de sistema de traducció (a la manera d'Star Trek) que permeti rebre ordres en veu en un idioma i executar-les en un altre idioma. Per exemple, l'usuari podria dir "tradueix 'obrir la porta' a l'anglès" i el sistema li respondria "open the door". Aquest prototip es basarà en la utilització de models pre-entrenats de huggingface per a la traducció i la síntesi de veu.

# %% [markdown]
# ## Recerca de models pre-entrenats
#
# El primer pas és buscar models pre-entrenats per les tasques sol·licitades. Investiga en huggingface per sel·leccionar els models que millor s'ajustin a les necessitats del prototip.
#
# Quan hagis seleccionat els models modifica les següents variables per incloure'ls en el prototip:

# %%
# Model de veu a text

MODEL_VEU_A_TEXT = ""

# Model de traducció català a castellà

MODEL_TRADUCCIO = ""

# Model de text a veu

MODEL_TEXT_A_VEU = ""

# %% [markdown]
# ## Implementació del prototip
#
# Un cop seleccionats els models pre-entrenats, implementa el prototip. Per fer-ho pots seguir els següents passos:
#
# 1. Crea una funció que, donada una ordre en veu, la transformi a text (_Automatic speech recognition_). Per fer-ho pots utilitzar el model `MODEL_VEU_A_TEXT` seleccionat anteriorment. Com a exemple pots utilitzar la següent ordre en veu: [obre_la_porta.wav](https://lawer.github.io/mia/apunts/7.-NLP/obre_la_porta.wav).

# %%
# Creem el pipeline per a la conversió de veu a text
from transformers import pipeline

##### Creem el pipeline per a la conversió de veu a text



#### Convertim la veu a text
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ' Obre la porta!'

# %% [markdown]
# 2. Crea una funció que, donada una ordre en text i un idioma, la tradueixi al castellà (_Machine translation_). Per fer-ho pots utilitzar el model `MODEL_TRADUCCIO` seleccionat anteriorment. Com a exemple pots utilitzar la següent ordre en text: "obre la porta".

# %%
#### Creem el pipeline per a la traducció


#### Traduïm el text al castellà
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:197: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# 'abre la puerta'

# %% [markdown]
# 3. Crea una funció que, donat un text, el sintetitzi en veu (_Text to speech_). Per fer-ho pots utilitzar el model `MODEL_TEXT_A_VEU` seleccionat anteriorment. Com a exemple pots utilitzar el text "abre la puerta".

# %%
#### Creem el pipeline per a la síntesi de veu


#### Sintetitzem el text en veu
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.

# %%
from IPython.display import Audio

Audio(out["audio"], rate=out['sampling_rate'])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# 4.- Uneix les tres funcions anteriors en una sola funció que, donada una ordre en veu i un idioma, la transformi a text, la tradueixi a un altre idioma i la sintetitzi en veu. Com a exemple pots utilitzar la següent ordre en veu: [obre_la_porta.wav](obre_la_porta.wav).

# %%
from IPython.display import Audio


def assistant(voice_order):
    # Convertim la veu a text
    
    # Traduïm el text al castellà

    # Sintetitzem el text en veu

    return out

out = assistant("obre_la_porta.wav")

Audio(out["audio"], rate=out['sampling_rate'])
# Out:
# text from audio:  Obre la porta!
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# text in spanish: ¡Abre la puerta!
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
